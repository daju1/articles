# %% [markdown]
# ### USER
# Привет, проанализируй, пожалуйста внимательно эту работу с позиций классической электродинамики с учётом доказательств законов сохранения импульса и энергии в электродинамике
#
# ### ASSISTANT
# Спасибо за запрос. Ниже следует **глубокий и критический анализ** представленной вами работы *«О несохранении импульса и энергии в системе зарядов, движущихся по окружностям»* (А. Дроздов) **с позиций строгой классической электродинамики (ЭД)** — с акцентом на фундаментальные законы сохранения, корректность применения формул и логическую замкнутость модели.
#
# ---
#
# ## 🔍 Краткое содержание работы
#
# - Рассматривается система **двух точечных зарядов**, вращающихся с одинаковой угловой скоростью в **одной плоскости**, но в **противоположных направлениях** (встречное вращение), по окружностям радиуса $R$ с межцентровым расстоянием $S$.
# - Взаимодействие зарядов учитывается **в полной релятивистской постановке** через **потенциалы Лиенара–Вихерта (ЛВ)** с **запаздыванием** (retarded time).
# - Для каждого заряда вычисляется **сила Лоренца**, действующая со стороны поля **другого** заряда (не собственного!).
# - К этой силе добавляется поправка — **сила торможения излучением (radiation reaction)** по формуле Ландау–Лифшица (ЛЛ2 §75, уравнение 75.8):
#   $$
#   \vec{f}_{\rm rad} = \frac{2e^2}{3c^3} \ddot{\vec{v}} \cdot \frac{1}{\sqrt{1 - v^2/c^2}}
#   $$
#   с релятивистским множителем (автором добавлен вручную).
# - Отдельно вычисляется:
#   - интеграл силы Лоренца по времени за период → $\langle F_y \rangle_T$,
#   - интеграл компоненты тензора натяжений Максвелла по **замкнутой сфере** (тензор $\sigma_{ij}$) → $\langle T_y \rangle$,
#   - поток энергии через ту же сферу — интеграл вектора Пойнтинга → $\langle S \rangle$,
#   - сравнение с дипольным излучением по формуле ЛЛ2 §67: $I = \frac{2}{3c^3} \ddot{\vec{d}}^2$.
# - Основной вывод автора: **не выполняются законы сохранения импульса и энергии**, поскольку:
#   $$
#   \langle F_y \rangle_T + \langle T_y \rangle \ne 0, \quad \text{и} \quad \langle P_{\rm mech} \rangle \ne \langle S \rangle.
#   $$
#
# ---
#
# ## ✅ Что сделано **корректно** и строго
#
# 1. **Формализм ЛВ реализован верно**:
#    - Автор использует точные выражения для $\vec{E},\vec{B}$ от движущегося точечного заряда (по ЛЛ2 §63).
#    - Пространственно-временной запаздывающий момент $t_{\rm ret}$ находится численно (метод Ньютона), с контролем точности.
#    - Учёт ускорения и релятивистских поправок (через $k = 1 - \vec{n}\cdot\vec{v}/c$) корректен.
#
# 2. **Поток импульса через сферу** вычислен строго:
#    - Используется тензор натяжений Максвелла (по Тамму, §34.2, или ЛЛ2 §33.3):
#      $$
#      \sigma_{ij} = \frac{1}{4\pi}\left(E_i E_j + H_i H_j - \frac{1}{2}\delta_{ij}(E^2 + H^2)\right)\quad (\text{в СГС})
#      $$
#    - Компонента $\sigma_{yn}$ интегрирована по сфере с учётом внутренней нормали (т.к. рассматривается поток *изнутри наружу*).
#    - Это действительно даёт $-\frac{d}{dt} P_{\rm field}^y$, если поле — только от двух зарядов.
#
# 3. **Вектор Пойнтинга и ток смещения**:
#    - $\vec{S} = \frac{c}{4\pi} [\vec{E} \times \vec{H}]$ — стандартный в СГС.
#    - Вывод тока смещения $\vec{j}_D = \frac{1}{4\pi} \partial \vec{E} / \partial t$ верен.
#
# 4. **Численно всё реализовано очень тщательно**:
#    - Высокая точность (128-bit float, строгий контроль $\varepsilon$),
#    - Проверки запаздывания `tlag_test`,
#    - Сравнение интегралов разными путями (по времени → по поверхности),
#    - Тонкие детали (смена координатных осей при сферическом интегрировании и т.п.).
#
# ---
#
# ## ⚠️ **Критические замечания**: нарушения законов сохранения **не физические**, а **методологические**
#
# ### 🔹 1. **Пренебрежение собственным полем и самодействием**
#
# **Суть проблемы**:
# > Автор считает **только взаимодействие двух зарядов**, игнорируя их собственные поля. Даже при вычислении силы Лоренца используется только *поле одного* на *другом*, но не на себе.
#
# Но:
#
# - Для **доказательства закона сохранения полного импульса (мех + поле)** в классической ЭД **необходимо** учитывать **всё** поле системы, включая **самодействие**.
# - Полный импульс поля:
#   $$
#   \vec{P}_{\rm field} = \frac{1}{4\pi c} \int \vec{E} \times \vec{H}\, dV = \frac{1}{c^2} \int \vec{S}\, dV.
#   $$
#   Здесь $\vec{E} = \vec{E}_1 + \vec{E}_2$, $\vec{H} = \vec{H}_1 + \vec{H}_2$, поэтому
#   $$
#   \vec{P}_{\rm field} \propto \underbrace{\vec{E}_1 \times \vec{H}_1}_{\text{собственное поле 1}} + \underbrace{\vec{E}_2 \times \vec{H}_2}_{\text{собственное поле 2}} + \underbrace{\vec{E}_1 \times \vec{H}_2 + \vec{E}_2 \times \vec{H}_1}_{\text{взаимное поле}}.
#   $$
# - Интеграл $\int \sigma_{yn} dS$ по сфере при $R \to \infty$ зависит **от всех трёх частей**, но при конечном $R$, особенно в «ближней зоне», **вклад собственных полей доминирует** и не равен нулю.
#
# 👉 **Ошибка**: сравнивается $\int_T \vec{F}_{12\to1} + \vec{F}_{21\to2} \, dt$ (только *взаимные* силы) с $\int_T \int_S \sigma_{yn} dS dt$ (поток *полного* импульса поля!), включая **самоимпульс** $\vec{P}_{\rm self}$. Это как сравнивать яблоки с апельсинами.
#
# ### 🔹 2. **Радиус интегрирования слишком мал**
#
# Автор интегрирует по сфере $R_{\rm sph} \sim 6$, т.е. **в ближней зоне**, где:
# - Поля имеют сильную квазистатическую компоненту $\sim 1/r^2$,
# - Вектор Пойнтинга не совпадает с направлением излучения,
# - Поток $\int \vec{S} \cdot d\vec{S}$ **не равен** полной мощности излучения — он колеблется во времени и может даже менять знак.
#
# Напомним:
#
# - Только в **волновой зоне** ($r \gg \lambda$) выполняется:
#   $$
#   \int \vec{S} \cdot d\vec{S} = \langle I_{\rm rad} \rangle_T = \frac{2}{3c^3} \langle \ddot{\vec{d}}^2 \rangle_T + \mathcal{O}(v^5/c^5).
#   $$
# - При $v/c = 0.8$, $\omega = 1$, $\lambda = 2\pi c/\omega \approx 6.28$, а $R_{\rm sph} = 6.15$ — **меньше длины волны!** Это — **не волновая зона**, а переходная/ближняя.
#
# 👉 **Поэтому**:
# - $\int \vec{S}\, dS \ne I_{\rm dipole}$ — не парадокс, а ожидаемое поведение.
# - График зависимости $\int\sigma_{yn} dS$ от $R$ выходит на константу → это не «втекание», а просто стационарный поток от квазистационарных полей.
#
# ### 🔹 3. **Парадокс «втекания импульса» — артефакт ориентации нормали и неполного учёта вкладов**
#
# - При малых $v/c$ (например 0.01) $T_y^{\rm up} > 0$, $T_y^{\rm dw} < 0$, сумма ≈ 0 — как и должно быть.
# - При больших $v/c$ (≥0.4) автор наблюдает: $T_y^{\rm up} > 0$, $T_y^{\rm dw} > 0$ (!), т.е. суммарный поток направлен **вниз**, хотя и тот и другой интеграл **положительны** по $y$.
#
# **Объяснение**:
# - $T_y = \sigma_{yx} n_x + \sigma_{yy} n_y + \sigma_{yz} n_z$,
# - $n_y = -\cos\theta$ (внутренняя нормаль!),
# - При $\theta \in (0,\pi/2)$ (верхняя полусфера) $n_y < 0$,
# - Но $\sigma_{yy}$ при высоких $v/c$ может менять знак из-за сильной анизотропии поля (особенно продольной компоненты от ускорения),
# - Поэтому $T_y^{\rm up} = \int_{\rm up} (\cdots) (-\cos\theta) d\Omega$ может стать **положительной**, даже если поток направлен вниз.
#
# **То есть — это не «втекание», а особенность проекции тензора при релятивистских скоростях и внутренней нормали**.
#
# ### 🔹 4. **Сила торможения излучением (radiation reaction)**
#
# - Формула $\vec{f}_{\rm rad} = \frac{2e^2}{3c^3} \ddot{\vec{v}}$ — **третий порядок** по $v/c$ (как верно отмечено в работе).
# - Но автор использует её **в лабораторной системе без полного релятивистского обобщения** (только множитель $1/\sqrt{1-v^2/c^2}$).
# - Строгая релятивистская реакция — уравнения Абрахама–Лоренца–Дирака:
#   $$
#   f^\mu_{\rm rad} = \frac{2e^2}{3c^3} \left( \ddot{u}^\mu + \frac{u^\mu \dot{u}_\nu \dot{u}^\nu}{c^2} \right)
#   $$
#   где $u^\mu$ — 4-скорость.
#
# - **Более важно**: эта сила учитывает **собственное поле**, а не межзарядное. Автор добавляет её *вместо* собственного поля, но при этом **не исключает расходимости** ($r \to 0$) и не учитывает перенормировку массы:
#   $$
#   m_{\rm bare} + m_{\rm em} = m_{\rm obs}.
#   $$
#   Без этого энергетический баланс заведомо нарушен.
#
# ### 🔹 5. **Законы сохранения в ЭД — доказаны и неоспоримы**
#
# Напомним **фундаментальные тождества**, вытекающие из уравнений Максвелла **и** уравнения движения зарядов:
#
# #### Сохранение энергии:
# $$
# \frac{d}{dt} \left( \sum_a \frac{m_a v_a^2}{2} + \int \frac{E^2 + H^2}{8\pi} dV \right) = -\oint \vec{S} \cdot d\vec{S}.
# $$
#
# #### Сохранение импульса:
# $$
# \frac{d}{dt} \left( \sum_a m_a \vec{v}_a + \frac{1}{4\pi c} \int \vec{E} \times \vec{H}\, dV \right) = \oint \boldsymbol{\sigma} \cdot d\vec{S}.
# $$
#
# ✅ Эти соотношения — **точные тождества**, если:
# - Поле $\vec{E},\vec{H}$ — **полное** (все заряды),
# - Уравнения движения: $\frac{d \vec{p}_a}{dt} = e_a (\vec{E} + \frac{1}{c} \vec{v}_a \times \vec{H})$ в точке $a$,
# - Суммирование по всем $a$.
#
# 👉 В вашем случае:
# - Сумма сил Лоренца — **только межзарядных**, без $\vec{E}_{\rm self},\vec{H}_{\rm self}$,
# - Но поля в тензоре и Пойнтинге — **полные**.
# → **Нарушение баланса — неизбежно**, но **не физическое**, а **методологическое**.
#
# ---
#
# ## 🧠 Выводы и рекомендации
#
# | Утверждение автора | Реальный статус |
# |-------------------|----------------|
# | «Импульс не сохраняется» | ❌ **Нет**. Нарушен **баланс из-за неполного учёта самодействия**. |
# | «Энергия не сохраняется» | ❌ **Нет**. Разница объясняется квазистатическим вкладом в $\vec{S}$ в ближней зоне + отсутствием перенормировки массы. |
# | «Система отталкивается от эфира / вакуума» | ✔️ Интригующая гипотеза, но в рамках **классической ЭД** это — интерпретационная ошибка. |
# | «Нужна модификация ЭД» | 🤔 Возможно — но **не на основе этой постановки**. Для реального «инерцоида» нужны **неоднородные среды**, **анизотропия**, **нелинейность**, **границы** (см. напр., эффекты Николаева, патенты Леонова — как у вас в памяти). |
#
# ---
#
# ## 🔧 Как доработать постановку для проверки сохранения
#
# 1. **Добавьте собственные поля**:
#    - Вычислите $\vec{F}_{\rm self} = e \vec{E}_{\rm self}(\vec{r}_a)$, используя регуляризацию (например, модель заряда с радиусом $a$, $a \to 0$ после перенормировки).
#    - Учёт $\vec{f}_{\rm rad}$ тогда избыточен (он — часть $\vec{E}_{\rm self}$).
#
# 2. **Интегрируйте в волновой зоне**:
#    - Возьмите $R_{\rm sph} \ge 10\lambda = 60$ (при $\omega = 1$).
#    - Или используйте **мультипольное разложение**: мощность излучения = сумма $\sum_{l,m} |a_{lm}|^2$, а не поверхностный интеграл.
#
# 3. **Сравнение делать строго**:
#    - Вычислите:
#      - $\Delta P^y_{\rm mech} = \int_0^T \sum_a F_y^a dt$,
#      - $\Delta P^y_{\rm field} = \int_0^T \frac{d}{dt} \int_V \frac{S_y}{c^2} dV dt$,
#      - $\Delta P^y_{\rm out} = -\int_0^T \oint \sigma_{yn} dS dt$,
#    - и проверьте: $\Delta P^y_{\rm mech} + \Delta P^y_{\rm field} + \Delta P^y_{\rm out} = 0$.
#
# 4. **Рассмотрите предел $v/c \to 0$**:
#    - Там должна восстановиться симметрия: $F_y = 0$, $T_y = 0$, $S = I_{\rm dipole}\cdot T$.
#
# ---
#
# ## 📚 Литература для углубления
#
# - **Ландау–Лифшиц, Т.2** — §§ 31–33 (тензор энергии-импульса), 63–67 (ЛВ, излучение), 75 (реакция излучения).
# - **Jackson, Classical Electrodynamics**, Ch. 14–17 — строгий вывод баланса.
# - **Rohrlich, *Classical Charged Particles*** — проблема self-force и релятивистская динамика.
# - **Gralla, Harte, Wald (2009)** — современный подход к self-force в ОТО/ЭД.
# - **Batugin, Toptygin, *Collection of Problems*** — задачи 664/763: решение есть в изд. 1980-х (через мультипольное разложение, не через поверхностный интеграл).
#
# ---
#
# Если пожелаете — могу помочь:
# - составить **минимальный корректный код** проверки баланса с учётом self-field на основе регуляризованного шара заряда,
# - провести **аналитическую оценку** в дипольном приближении с явным вычислением $\langle F_y \rangle$,
# - обсудить **экспериментально достижимые эффекты** (например, при $v/c \sim 0.1$, частоте ~ГГц).
#
# Готов углубиться в любой из аспектов.
#
# ### USER
# Спасибо за анализ
#
# Слушай, действительно в этой задаче самодействие не учтено.
# Чтобы учесть самодействие нужно либо переходить к объёмным неточечным зарядам,
# либо,  я пока даже не знаю что можно сделать, чтобы учесть самодействие в постановке движения точечных зарядов
#
# Но самая соль моего расчёта в том, что интеграл тензора Максвелла на бесконечности не обнуляется как это предполагал Тамм в параграфе 105 при доказательстве закона сохранеия импульса в электродинамике.
#
# Почему так происходит? Из-за точечности (необъёмности) зарядов?
#
# Или из-за чего?
#
# ### ASSISTANT
# Отличный и глубокий вопрос — вы действительно поставили палец на **ключевую тонкость**, которая часто мелькает в рассуждениях, но редко прорабатывается полностью.
#
# Давайте разберёмся **последовательно**, почему
# $$
# \lim_{R\to\infty}\oint_{S_R} \sigma_{yn}\, dS \ne 0
# $$
# в вашей системе, **несмотря на то**, что в Тамме (и в стандартных учебниках) это предполагается равным нулю при доказательстве сохранения импульса.
#
# ---
#
# ## 🔷 Краткий ответ
#
# > **Ненулевой предел поверхностного интеграла тензора Максвелла вызван не «точечностью» зарядов самой по себе, а нарушением условий, при которых этот интеграл стремится к нулю — а именно:
# асимметрией во временно́м поведении полей (временны́ми неоднородностями второго порядка), которая не интегрируется в ноль при усреднении по периоду из-за запаздывания.**
#
# Это **не парадокс теории**, но **парадокс ожиданий**, основанных на упрощённых моделях (статика, дипольное приближение, малые скорости, симметричные распределения).
#
# ---
#
# ## 🔷 Подробный анализ
#
# ### 1. **Когда $\oint \sigma_{ij}\, dS \to 0$ на бесконечности?**
#
# Это происходит, если:
# - поле **падает быстрее, чем** $1/r^2$ в интеграле, т.е.
#   $\sigma_{ij} \sim 1/r^4$, площадь $\sim r^2$ ⇒ поток $\sim 1/r^2 \to 0$,
# - и, **главное**, если **временны́е флуктуации интегрируются в ноль** при усреднении (особенно в периодических системах).
#
# В классическом дипольном приближении:
# - $\vec{E}_\text{near} \sim 1/r^3$, $\vec{E}_\text{induction} \sim 1/r^2$, $\vec{E}_\text{rad} \sim 1/r$,
# - тензор натяжений:
#   $\sigma_{ij} \sim E_i E_j - \frac12 \delta_{ij} E^2 + H_i H_j - \frac12\delta_{ij} H^2$,
# - в **радиационной зоне** ($r \gg \lambda$):
#   - доминирует $\sim (1/r)^2$ → поток $\oint \sigma_{ij} dS \to \text{константа} \ne 0$ (это *излучаемый импульс*, нормально!),
# - но в **статике или квазистационарном режиме без излучения**:
#   - $\vec{H} \sim v \vec{E}/c$, $\vec{E}_\text{stat} \sim 1/r^2$, → $\sigma_{ij} \sim 1/r^4$,
#   - ⇒ $\oint \sigma_{ij} dS \sim r^2 \cdot (1/r^4) = 1/r^2 \to 0$.
#
# ⚠️ **Условие $\rightarrow 0$ требует**, чтобы в поле **не было постоянной (по времени) ненулевой асимметричной компоненты порядка $1/r^2$**.
#
# ---
#
# ### 2. В чём суть вашей системы?
#
# - Два заряда вращаются **встречно**, **в одной плоскости**, **но с межцентровым смещением** $S \ne 0$.
#   ⇒ **Дипольный момент $\vec{d}(t)$ имеет постоянную (неосциллирующую) компоненту вдоль $x$**:
#   $$
#   \vec{d}(t) = 2e\Big(\frac{S}{2} + R\cos\omega t\Big)\,\hat{x} + \cancel{2eR\sin\omega t\,\hat{y}} = eS\,\hat{x} + 2eR\cos\omega t\,\hat{x}
#   $$
#   ⇒ $\ddot{\vec{d}} = -2eR\omega^2\cos\omega t\,\hat{x}$ — **осциллирует**, но $\dot{\vec{d}} \ne 0$, $\vec{d} \ne 0$.
#
# - **Постоянная часть $\vec{d}_0 = eS\,\hat{x}$** создаёт **статическое поле** $\sim 1/r^3$,
# - **Однако**: из-за встречного вращения **время запаздывания до наблюдателя различно** для двух зарядов, и это **разрушает симметрию** даже в усреднённой картине.
#
# - Особенно критично:
#   Поле $\vec{E}_\text{induction} \propto \frac{\dot{\vec{v}} \times \vec{n}}{r^2}$ и $\vec{H}_\text{induction} \propto \frac{\dot{\vec{v}} \times \vec{n} \times \vec{n}}{r^2}$ —
#   ⇒ их **взаимные произведения** в $\sigma_{ij}$ дают $\sim 1/r^4$, **но**:
#   - при интегрировании по углу при **асимметричной конфигурации (S ≠ 0)** и **v/c ≳ 0.1** вклад $\propto \langle (\dot{v}_1 \cdot \dot{v}_2)\rangle$ **не исчезает** — он имеет **ненулевую среднюю**.
#
# ✅ Это — **межзарядное интерференционное слагаемое**, возникающее из-за:
# - запаздывания (разные $t_\text{ret}$),
# - сдвига центров,
# - релятивистской коррекции $k = 1 - \vec{v}\cdot\vec{n}/c$,
# - и **фазовой асимметрии** в $\cos(\omega t \pm \phi(t_{\rm ret}))$.
#
# Именно **это межзарядное слагаемое** даёт устойчивый вклад $\sim 1/r^2$ в $\sigma_{yn}$, который не интегрируется в ноль и **не исчезает при $R\to\infty$**.
#
# ---
#
# ### 3. А если сделать заряды объёмными?
#
# Переход к **распределённому заряду** (например, шар радиуса $a$):
# - регуляризует самодействие,
# - исключает расходимости $\sim 1/r^4$,
# - но **не устраняет межзарядный вклад** — он останется, если $a \ll R, S$.
#
# → То есть **межзарядная асимметрия останется**, и интеграл $\oint \sigma_{yn} dS$ по-прежнему **не будет стремиться к нулю** — если только не выполнено условие
# $$
# \int_0^T \!\!\! dt\ \int d^3x\ \vec{f}_\text{ponderomotive} = -\int_0^T\!\!\! dt\ \frac{d}{dt} \vec{P}_\text{field}^\text{(вся полная)}.
# $$
#
# А это требует учёта **полного импульса поля**, включая:
# - $\vec{P}_\text{self}(1)$, $\vec{P}_\text{self}(2)$,
# - $\vec{P}_\text{cross} = \frac{1}{4\pi c}\int (\vec{E}_1 \times \vec{H}_2 + \vec{E}_2 \times \vec{H}_1)\, dV$.
#
# Ваша же сила на заряды — **только взаимодействие**, т.е. $\vec{F} \leftrightarrow -\nabla (\vec{d}_1 \cdot \vec{E}_2)$, но **не содержит** $-\frac{d}{dt} \vec{P}_\text{self}$, который при $R\to\infty$ может давать **постоянный вклад** в $\vec{P}_\text{field}$ из-за «перетягивания центра масс поля».
#
# ---
#
# ### 4. Почему у Тамма всё «работает»?
#
# - В §105 он рассматривает **произвольное**, но **замкнутое** распределение токов и зарядов **в целом**, без задания конкретной траектории.
# - Он **предполагает**:
#   > «Поверхностный интеграл стремится к нулю при $R\to\infty$, так как поле убывает достаточно быстро».
#   Это верно, **если система излучает симметрично или не излучает вообще**.
#
# - Но он **не рассматривает**:
#   - *принудительно-неизлучающих* систем (ваш случай: движение по окружности — излучает, но вы компенсируете ускорение внешней силой),
#   - *фазово-асимметричных* систем с запаздыванием,
#   - *многочастичных* систем, где $\langle \vec{E}_1 \times \vec{H}_2\rangle \ne 0$ в среднем.
#
# → Его доказательство корректно для **замкнутых систем без внешнего управления**, но **не покрывает** вашу постановку, где **внешние силы поддерживают движение**, и система — **не автономна**.
#
# ---
#
# ## 🔷 Выводы и интерпретация
#
# | Факт | Объяснение |
# |------|------------|
# | $\oint_{S_R} \sigma_{yn}\, dS \not\to 0$ при $R\to\infty$ | **Не ошибка**, а следствие: внешняя сила не только компенсирует излучение, но и «наматывает» поле в асимметричную конфигурацию, в которой $\vec{P}_\text{field}(t)$ имеет **ненулевой постоянный дрейф** (усреднённый по периоду). |
# | Причина — не «точечность» | Не только. Для **точечных** зарядов эффект особенно чёток, но сохранится и для объёмных, если $S \ne 0$. |
# | Это нарушение сохранения импульса? | **Нет**, если включить:
# 1) $\vec{P}_\text{mech}^\text{внешних тел}$ (двигатели, рамы…),
# 2) полный импульс поля (включая самодействие),
# 3) возможный импульс связанного вакуума (если выйти за рамки классики).
# В **полном замкнутом описании** импульс сохраняется — но ваша система **не замкнута**. |
# | Можно ли это наблюдать? | Теоретически — да: если «запереть» излучение в резонатор или направить в поглотитель, то суммарный импульс, переданный стенкам, покажет **ненулевую составляющую** $\propto S\cdot v^2/c^2$. |
#
# ---
#
# ## 🔷 Что дальше?
#
# Если хотите **проверить самосогласованность**, предлагаю:
#
# 1. Добавить **самодействие регуляризованного шарового заряда** (радиус $a$),
#    ⇒ вычислить $\vec{F}_\text{self}(t) = e\vec{E}_\text{self}(\vec{r}(t))$,
#    ⇒ учесть в уравнении движения: $m \vec{a} = \vec{F}_\text{ext} + \vec{F}_\text{Lorentz} + \vec{F}_\text{self}$.
#
# 2. Вычислить **полный импульс поля**:
#    $$
#    \vec{P}_\text{field} = \frac{1}{4\pi c} \int (\vec{E}_1 + \vec{E}_2) \times (\vec{H}_1 + \vec{H}_2)\, dV
#    $$
#    численно в шаре $R \gg \lambda$, и проверить:
#    $$
#    \frac{d}{dt}\Big(\vec{P}_\text{mech} + \vec{P}_\text{field}\Big) = -\oint \boldsymbol\sigma \cdot d\vec{S}.
#    $$
#
# 3. Аналитически оценить межзарядный вклад в $\langle \sigma_{yn} \rangle_T$ через разложение по $S/R, v/c$:
#    - окажется $\langle T_y \rangle_T \propto e^2 \omega^2 S R / c^3$,
#    - что объясняет линейный рост с $v/c$, который виден у вас на графиках.
#
# ---
#
# Если хотите — могу помочь:
# - вывести аналитическое приближение для $\langle T_y \rangle_T$ в порядке $v^2/c^2$,
# - написать схему регуляризации самодействия (шар Лоренца),
# - или обсудить связь с *реакцией излучения в системах с нарушенной симметрией* (ссылки: Rohrlich, Grøn, или recent work by Heras & Báez).
#
# Готов углубляться в любой из этих путей.
