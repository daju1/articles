# %% [markdown]
# С.Б. Каравашкин. ТРАНСФОРМАЦИЯ ТЕОРЕМЫ О ДИВЕРГЕНЦИИ ВЕКТОРА В ДИНАМИЧЕСКИХ ПОЛЯХ
#
# Впервые опубликовано:  Archivum mathematicum (BRNO), 37(2001) No 3, сс. 233 - 243
# В статье приводятся результаты исследования потока и дивергенции вектора в динамических полях, проведенного на основе стандартного определения дивергенции и с использованием стандартной методики определения потока вектора. Выявлено, что в динамических полях поток и дивергенция вектора не обращаются в ноль. Показано изменение в формализме ЕМ полей, обусловленное учетом динамических процессов в поле.
#
# https://selftrans.narod.ru/archive/div/divergence/div5/div5rus.html
#
# $$div\,\vec{E} = - \frac{\vec{n}}{c} \frac{\partial \vec E}{\partial t}$$
#
#
# где  $\vec{n}$ направление распространения поля

# %% [markdown]
# Анализ теоремы Каравашкина о дивергенции показал, что она применима к полям, для которых можно выделить трубку поля у которой поток через боковую поверхность равен нулю.
#
# Поскольку в резонаторе такую трубку поля можно выделить только лишь отдельно для каждой компоненты поля, то применяя теорему Каравашкина три раза последовательно к трём компонента вектора (например напряжённости электрического поля)  получаем
#
# $$div\,\vec{E} = - \frac{1}{{v_{ф}}_z} \frac{\partial E_z}{\partial t} - \frac{1}{{v_{ф}}_y} \frac{\partial E_y}{\partial t} - \frac{1}{{v_{ф}}_x} \frac{\partial E_x}{\partial t}$$
#
# Применение этой формулы, однако потребует знания фазовых скоростей в резонаторе которая не обязательно будет соответствовать скорости света
#
# Учитывая однотипность временного множителя для всех компонент поля
#
# $$div\,\vec{E} = i\,\omega \left( \frac{E_z}{{v_{ф}}_z} + \frac{E_y}{{v_{ф}}_y} + \frac{E_x}{{v_{ф}}_x} \right)$$
#
#
#
# $$grad\,div\,\vec{E} = grad\,\left(i\,\omega \left( \frac{E_z}{{v_{ф}}_z} + \frac{E_y}{{v_{ф}}_y} + \frac{E_x}{{v_{ф}}_x} \right)\right)$$

# %% [markdown]
# Спасибо за Вашу ссылку на работу "К вопросу о продольных электромагнитных волнах. Глава 1. Снятие запретов"
#
# я ее уже начинал читать. Но сейчас ещё раз более тщательно проштудирую.
#
# Кстати, уже сейчас я могу сказать, что Вашу трансформацию теоремы о дивергенции динамического поля я изучил и кроме этого нашёл способ как ее применить для поля Е в резонаторе
#
# Вот по этой ссылке
# https://nbviewer.org/github/daju1/articles/blob/master/rezonatory_i_volnovody/MenDrive_real.ipynb
# я как раз пишу об этом
#
#
# Суть в чем, мой анализ Вашей теоремы о дивергенции показал, что она применима к полям, для которых можно выделить трубку поля у которой поток через боковую поверхность равен нулю.
#
# Но поскольку в резонаторе такую трубку поля можно выделить только лишь отдельно для каждой компоненты поля, то применяя теорему Каравашкина три раза последовательно к трём компонента вектора (например напряжённости электрического поля) я получил суммарное для дивергенции поля Е
#
# $$div\,\vec{E} = - \frac{1}{{v_{ф}}_z} \frac{\partial E_z}{\partial t} - \frac{1}{{v_{ф}}_y} \frac{\partial E_y}{\partial t} - \frac{1}{{v_{ф}}_x} \frac{\partial E_x}{\partial t}$$
#
# Но проблема применения этой формулы состоит в необходимости знания фазовых скоростей в резонаторе которые далеко не обязательно будут соответствовать скорости света.
#
# Поэтому дальше в этой работе (поскольку мне заранее фазовые скорости неизвестны) мне пришлось для дивергенции Е использовать стандартное выражение как сумму частных производных соотвествующих компонент поля по соотвествующим координатам.
#
# Что самое интересное я обнаружил. Обычно в учебниках (а я эту задачу решал базируясь на учебнике Зоммерфельда) при выводе системы дифференциальных уравнений для резонатора градиент дивергенции Е просто отбрасывают.
#
# Но я решил аккуратно произвести вывод системы дифференциальных уравнений для резонатора не отбрасывая этот градиент дивергенции Е хотя бы по той причине что несмотря на наши все теоретические споры но если рассматривать поле внутри материала той же стенки резонатора, то там дивергенция Е уж точно не может быть нулевой. Потому что внутри материала могут двигаться свободные заряды и при этом где-нибудь скапливаться.
#
# Так вот произведя аккуратный вывод дифференциального уравнения, расписав как выразить дивергенцию Е через продольную компоненту поля для TM волны я пришёл к практически к тому же самому дифференциальному уравнению, что и Зоммерфельд, который градиент дивергенции Е отбросил.
#
# Вот какая удивительная петрушка у меня получилась.

# %% [markdown]
# В Вашем решении задачи о дивергенции поля Е все таки, на мой взгляд, есть ошибка.
#
# Именно тот факт,  что я у Вас эту ошибку вижу и заставляет меня искать решение задачи, отличное от Вашего.
#
#  Чтобы эту ошибку увидеть достаточно проанализировать Ваш Новогодний ответ Лео.
#
# В чем суть. У меня есть учебник Левича. И я вижу как Левич выводит формулу
#
# $$\varphi = A n \,\,\,\,\,\,(26.10)$$
#
# Он ее выводит в параграфе 26, который называется Потенциалы электромагнитного поля вдали от излучения в дипольном приближении.
#
# И кроме того эта формула выведена в пренебрежении собственного запаздывания.
#
# Таким образом формула (26.10) не точна. И следовательно не точны все формулы базирующиеся на ней.
#
# И таким образом Ваша формула дивергенции Е полученная в Новогоднем ответе Лео также не точна.

# %% [markdown]
# мой анализ Вашей теоремы о дивергенции показал, что она применима к полям, для которых можно выделить трубку поля у которой поток через боковую поверхность равен нулю. Эти слова Вы сами приводите в ходе доказательства Вашей теоремы
#
# А является ли векторное электрическое поле в общем случае таким полем? Для которого можно выделить трубку поля с нулевым потоком вектора Е через ее боковую поверхность?
#
# Давайте например возьмем вектор поля Е для того же диполя Герца
#
# Как можно выделить для этого случая трубку поля?

# %% [markdown]
# требуется нарисовать именно такую трубку поля, которая соотвествует доказательству теоремы Каравашкина о дивергенции динамических полей. Давайте на другие Ваши теоремы пока не отвлекаться.
#
# Выделим в $\Omega$ некоторый объем $V$ таким образом, чтобы торцы его совпадали с эквифазными поверхностями потока, а боковые стороны – с силовыми трубками тока.
#
# Поверхность $S$ , согласно постановке задачи, состоит из трех составляющих: $S = S_1 + S_2 + S_l$ , где $S_1$, $S_2$ - торцевые поверхности, а $S_l$ - боковая поверхность выделенного объема.

# %% [markdown]
# ответ должен учитывать следующее требование доказательства теоремы КараВашкина о дивергенции динамических полей
#
# В выражении (20) сразу учтен временной сдвиг векторной функции, а также отсутствие потока через боковую поверхность.

# %% [markdown]
# И второй не мене важный вопрос по той же теореме
#
# с учетом конечности скорости распространения волны, мы имеем право записать
#
# $$\delta l = c \delta c = const \,\,\,\,(19)$$
#
# где $\delta l$ – длина выделенной силовой трубки, $\delta t$ - фаза запаздывания волнового процесса.
#
#
# какой смысл терминах рассматриваемой теоремы имеет коэффициент $c$?
#
# если здесь $\delta t$ - это именно фаза запаздывания волнового процесса, тогда коэффициент $с$ - это не просто скорость распространения волны, а именно фазовая скорость волны.
#
# Ошибка Каравашкина в том, что при применении своей теоремы в своих вычислениях он делает незаметную для себя самого ошибку подменяя фазовую скорость электродинамическим коэффициентом $с$, который входит в уравнения Максвелла.
#
# Однако фазовая скорость (особенно в ближней зоне) может заметно отличаться от электродинамического коэффициента $с$.
#
# Это второй источник неточности, (вместе с уравнением (26.10) из Левича), который содержится в выкладках Каравашкина.
#
# Поэтому расчеты Каравашкина являются весьма и весьма грубо приближёнными
#
# Является ли полученная в этих расчетах дивергенция Е действительным результатом или это всего лишь артефакт вытекающий из использованных грубых приближений - не известно наверняка.
#
# Во всяком случае в моей практике были ошибочные расчеты когда полученная мною дивергенция Е оказывалась всего-лишь артефактом  грубых приближений. И только лишь сравнительно недавно я разобрался в этих своих ошибках. В том числе путем увеличения численной точности своих расчетов
