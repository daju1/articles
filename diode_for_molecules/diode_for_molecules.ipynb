# %% [markdown]
# # Диод для молекул

# %% [markdown]
# Предыстория вопроса такова
#
# В работе "Синтетический «демон» Максвелла", опубликованной в журнале «Химия и жизнь», 2001, №12 (http://daju.narod.ru/Maxwell/SintMaxwDem.htm) мною была сформулирована следующая идея: "для реализации идеи Максвелла ... нужно создать такую молекулярную систему, в которой пространственные затруднения для теплового движения молекул рабочей жидкости в одном направлении были бы меньшими, чем в противоположном."
#
# Данную идею я пытался реализовать в следующих работах:
#
# - "Жидкокристаллический двигатель или акустомеханический преобразователь", 4-6 января 2010 г – 17 июля 2010 г., http://liquidcrystalosmos.narod.ru/liquidcrystalengine.htm
#
# - Жидкокристаллический осмос или о возможности нарушения принципа детального равновесия в жидкокристаллической дисклинации, 17.11.2010, http://liquidcrystalosmos.narod.ru/liquidcrystalosmos.htm
#
# - Жидкокристаллический осмос или о возможности нарушения принципа детального равновесия в жидкокристаллической дисклинации, переработанный и исправленный вариант, Dec 15, 2022,  https://nbviewer.org/github/daju1/articles/blob/master/liquidcrystalosmos/liquidcrystalosmos.ipynb

# %% [markdown]
# Поэтому неслучайно моё внимание привлекла идея под названием
#
# - Диод для молекул, Гладких Эдуард Николаевич (contrentrop) http://www.sciteclibrary.ru/cgi-bin/yabb2/YaBB.pl?num=1525780324/40#40
#
# Процитирую рассуждения автора идеи

# %% [markdown]
# <i>Предлагается устройство (способ) пропускающее молекулы (атомы) газа в одну строну и не пропускающее в обратную – диод для молекул. Принцип действия диода таков:</i>

# %% [markdown]
# ![_zpsnsikzndv.jpg](images/_zpsnsikzndv.jpg)

# %% [markdown]
# <i>Рассмотрим рисунок 1. На нём изображён пустотелый конус в осевом сечении с открытым раструбом. Со стороны раструба пустим в него частицу в произвольном направлении. Легко видеть, что после каждого отражения от внутренней поверхности конуса, следующий угол падения будет меньше предыдущего. Таким образом, после нескольких отражений частица, летящая в конус, вылетит обратно.
#
# Теперь у конуса срежем вершину, создав в нём отверстие, как показано на рисунке 2, и пустим в него частицу. Легко видеть, что любая частица, залетающая в это отверстие, гарантированно пролетает диод и не возвращается обратно.
#
# Таким образом, мы получаем устройство, могущее пропускать молекулы газа преимущественно в одну сторону. Не обязательно чтобы все до единой молекулы проходили через диод со стороны входа и все до единой не проходили диод со стороны выхода. Достаточно, если будет хоть какой-то перевес числа молекул, идущих в прямом направлении, над идущими обратно. Хотя бы в доли процента.
#
# Возникает возражение: у усечённого конуса площадь входа меньше площади выхода, следовательно, на выход с обратной стороны падает больше молекул, чем на вход. Часть из них отражается в диоде, а часть всё-таки пролетает диод в обратном направлении и их число равно числу «прямолетящих» молекул.
# Докажем, что это не так.
#
# Доказательство первое. Рассмотрим рисунки 3 и 4. Всё, как водится, идеальное. Размер входного отверстия устремим к нулю. Легко видеть, что в прямом направлении пролетают все молекулы падающее на вход – в угловом секторе 180 градусов. Пролететь диод обратно могут только молекулы из углового сектора Б. Их меньше. Стало быть: диод работает.
#
# Доказательство второе. Самое простое очевидное и очень легко проверяемое. Самые ленивые могут его просто посмотреть здесь:
#
# https://www.youtube.com/watch?v=2cJSdVF7Tck
#
# Менее ленивые могут его повторить самостоятельно. Любой желающий посредством листа бумаги и ручки через несколько минут сможет сам убедиться в работоспособности диода.
# Рисуем перегородку, диод и примерно равные объёмы пространства слева и справа от диода. Пустим в этот объём одну молекулу. Рассмотрим траекторию этой молекулы на протяжении большого количества ударов. Такая модель вполне допустима, поскольку, напомню, газ в области диода бесстолкновительный и каждая молекула летает так, будто других молекул нет. Видим, что молекула чаще бывает со стороны широкой части раструба, следовательно – диод работает. Проверяйте.
#
#
# Самым наглядным и убедительным доказательством неравенства числа «прямолетящих» и «обратнолетящих» молекул считаю компьютерную модель диода. Нужно составить программу, которая бы считала «прямолетящие» и «обратнолетящие» молекулы при любых формах диода. Я программировать не умею. Умеющие программировать и заинтересовавшиеся диодом, - действуйте.
# Несложно догадаться где и как его можно использовать.
#
# Первое:
# Сосуд с газом перегораживаем перегородкой с диодами (рисунок 6) и по обе стороны перегородки, в результате действия диода, самопроизвольно устанавливается разность концентраций и, соответственно, давлений, которую мы можем превратить в работу. Вследствие отбора энергии из системы в виде работы, система будет непрерывно охлаждаться и, соответственно, непрерывно будет поглощать теплоту из окружающей среды, превращая её затем в работу. Типичный ВД2.
#
# Второе:
# В результате работы диода, по обе стороны пластины с диодами самопроизвольно создаётся разность давлений – подъёмная сила (рисунок 7). Что даёт возможность создания летательных аппаратов. Хотя бы и ковра-самолёта.
#
# Обсудим теперь детали. Первое.
#
# Чтобы диод заработал, нужно, чтобы молекулы внутри него не сталкивались друг другом, иначе будут искажаться траектории молекул, определяемые законом – угол падения равен углу отражения. Этого можно достичь, если диод сделать очень маленьким, сопоставимым с длиной свободного пробега молекул. Трудновато, но в современной технике возможно: размер отдельных элементов в микросхеме достигает 1 мкм, длина свободного пробега молекул примерно такая же. К тому же длину свободного пробега можно неограниченно увеличивать, расширяя газ. То есть, это проблема разрешима современной техникой. Диоды можно будет, например, прожигать лазером в алюминиевой плёнке или делать методом фотолитографии, как микросхемы.
#
# Второе. Сам диод сделан из трясущихся атомов, следовательно, его поверхность корявая и отражения по закону «угол падения равен углу отражения» не получится. Разумеется, этот фактор сильно исказит работу диода. Для уменьшения этого искажения можно подобрать газ из крупных молекул –существенно крупнее атомов самого диода. Что-то органическое – у органики молекулы крупные. Тогда поверхность, состоящая из маленьких атомов, будет примерно ровной в сравнении с крупными молекулами газа.
#
# Можно добавить, что конус – не единственная форма для диода. Их можно придумать – множество: комбинация конусов, щели, кольца и т.д. Например, рисунки 8 и 9 – здесь подобрана одинаковость площадей входа и выхода. Для тех, кто не верит в неравновесность диода при разных площадях входа/выхода – можно обсудить эту форму диода. Хорошо бы их все испытать на компьютерной модели. Пока всё</i>

# %% [markdown]
# <i>газ должен быть сильно разреженным, чтобы среднее расстояние между молекулами было сопоставимо с размером диода. размер диода сравним со средним расстоянием между молекулами газа и малое отверстие диода существенно больше размера молекул газа (иначе межмолекулярные силы закупорят это отверстие).</i>

# %% [markdown]
# Конец цитаты

# %% [markdown]
# Для конфигурации "Диод для молекул" был выполнен расчёт методом молекулярной динамики. За основу молекулярной модели была взята коническая нанотрубка, которая была модифицирована и превращена в ячейку молекулярной мембраны с порой конической формы.
# Кроме того в систему было добавлено 14 атомов неона.
#
# https://github.com/daju1/moldyn/tree/main/conicnanotube.03

# %% [markdown]
# ![conicnanotube.03.van_der_waals.png](images/conicnanotube.03.van_der_waals.png)

# %% [markdown]
# размер ячейки при инициализации (1.662756, 1.664886, 4) нм

# %%
# 0.836866 0.830433
xyz = (2*0.836866, 2*0.830433, 2*2)
xyz
# Out:
# (1.67373200000000, 1.66086600000000, 4)

# %% [markdown]
# обьем ячейки, нм^3

# %%
vol = xyz[0] * xyz[1] * xyz[2]
vol
# Out:
# 11.1193782876480

# %% [markdown]
# На всех трёх осях были заданы периодические граничные условия. Это значит, что если атом вылетел за пределы прямоугольной расчётной ячейки, то считается что он залетел с той же скоростью но с противоположной стороны.

# %% [markdown]
# исходные коды программы ghemical, которую я использую для МД моделирования, взяты отсюда
# https://www.bioinformatics.org/ghemical/download/release20111012/
#
# Но в целях проведения эксперимента данные коды были модифицированы набором патчей
#
# https://github.com/daju1/winlibghemical/tree/master/linux/release20111012
#
# который в среде докер
#
# https://github.com/daju1/winlibghemical/tree/master/linux/release20111012/docker
#
# собираются следующим набором комманд

# %% [markdown]
# 	make download
# 	make getcodes
# 	make all

# %% [markdown]
# Был разработаны также и рабочий пример для запуска моделирования из консольной программы без визуального интерфейса
#
# https://github.com/daju1/winlibghemical/blob/master/linux/release20111012/examples/example_moldyn.cpp
#
# А непосредственно для запуска моделирования использовался следующий скрипт
#
# https://github.com/daju1/winlibghemical/blob/master/linux/release20111012/examples/example_moldyn.01.sh
#
#
# В алгоритм программы МД закладываются потенциалы взаимодействия атомов друг с другом, в частности
#
# https://ru.wikipedia.org/wiki/Потенциал_Леннард-Джонса
#
# В программе, которую использовал я, используется
#
# http://open-babel.readthedocs.io/en/latest/Forcefields/ghemical.html

# %% [markdown]
# Моделирование наномембраны встречает на своём пути две основные трудности:
#
# 1) реализация таких граничных условий, которые обеспечивают устойчивое существование наномембраны как таковой - в натянутом состоянии посреди элементарной ячейки параллельно одной из её граней, например, параллельно плоскости XY;
#
# 2) автоматическая подстройка (оптимизация) размера элементарной ячейки.
#
# Решение первой трудности заключается в следующем. Для начала реализуем самую простую численную модель наномембраны, состоящей из однослойной графитной плоскости. Пусть элементарная ячейка включает в себя следующий фрагмент мембраны:

# %% [markdown]
# ![graphite.png](images/graphite.png)

# %% [markdown]
# На этом рисунке химические связи, показанные пунктирной линией, означают связи, отрезаемые границами элементарной ячейки:

# %% [markdown]
# ![graphite_in_cell.jpg](images/graphite_in_cell.jpg)

# %% [markdown]
# Чтобы обеспечить натяжение и свободное молекулярное перемещение такой наномембраны, разрезаемые границами элементарной ячейки связи периодически соединяем друг с другом:

# %% [markdown]
# ![graphite_membrane.png](images/graphite_membrane.png)

# %% [markdown]
# А это так выглядят периодическе граничные связи в модели мембраны с порой из конической нанотрубки

# %% [markdown]
# ![conicnanotube.03.png](images/conicnanotube.03.png)

# %% [markdown]
# Но для того, чтобы при оптимизации геометрии и при молекулярной динамике данная структура не свернулась «клубочком», в традиционный  алгоритм необходимо внести следующие изменения.
#
# Во-первых, необходимо изменить функциональность функции CheckLocations(), собственно, обеспечивающей реализацию периодических граничных условий. Назначение этой функции состоит в том, чтобы периодически проверять координаты молекул и, те молекулы, которые выходят за границы элементарной периодической ячейки, возвращать в эту ячейку с противоположной стороны. Необходимое изменение данной функции состоит в том, чтобы применять её не к молекулам, а к отдельным атомам. При этом корректно обрабатываются периодические граничные условия для молекул, размеры которых сравнимы с размерами самой элементарной ячейки, важнейшей из которых является сама наномембрана.
#
# Во-вторых, видоизменяется алгоритм вычисления потенциальной энергии, соответствующей энергии валентных взаимодействий, энергии валентных и торсионных углов молекул. Необходимое изменение состоит в методике расчёта расстояния между связанными атомами. Если модуль проекции расстояния между связанными атомами больше половины соответствующего размера периодической ячейки, то она (проекция расстояния между связанными атомами) сокращается на размер периодической ячейки:

# %% [markdown]
# 	if (r[dim] < - periodic_box_HALFdim[dim])
# 	{
# 		r[dim] += 2.0 * periodic_box_HALFdim[dim];
# 	}
# 	else if (r[dim] > + periodic_box_HALFdim[dim])
# 	{
# 		r[dim] -= 2.0 * periodic_box_HALFdim[dim];
# 	}

# %% [markdown]
# При этом разрезаемые границами элементарной ячейки связи, периодически соединённые друг с другом приобретают нормальную длину. А силы, связывающие эти атомы, поддерживают наномембрану в натянутом состоянии.
#
# После этого остаётся ещё одна проблема: потенциальная энергия мембраны зависит от размера элементарной ячейки. И если первоначально заданный размер задан неудачно, потенциальная энергия мембраны может «зашкаливать», вследствие, например, чрезмерного натяжения. Это чрезмерное натяжение является нежелательным, так как оно изменяет структуру мембраны и таким образом мешает исследованию.
#
# Решение проблемы состоит в реализации класса C++, производного от класса conjugate_gradient из библиотеки libghemical-1.90 обеспечивающего подстройку размеров элементарной ячейки, путём минимизации потенциальной энергии системы методом градиентного спуска в трёх координатах, каждая из которых есть размер элементарной ячейки.
#
# Таким образом, решаются технические проблемы, связанные с моделированием наномембраны в условиях периодической элементарной ячейки.

# %% [markdown]
# Кроме того, в рамках целей эксперимента были проведены ещё две важные модификации алгоритма
#
# 1) Инициализация начальных скоростей атомов в соответствии с распределением Максвелла по скоростям с одновременным наложением требования, чтобы суммарный импульс атомов мембраны и суммарный импульс атомов газа был нулевым. Чтобы изначальное движение по инерции со средней скоростью инициализации было исключено
#
# 2) Алгоритм термостата был модифицирован таким образом, чтобы коррекция скоростей атомов с целью поддержания модели при постоянной температуре сопровождалась требованием сохранения нулевого суммарного импульса всех атомов модели (суммарно мембраны и газа)

# %% [markdown]
# График на рисунке ниже это $z$ координата одного из атомов мембраны в завиимости от моделируемого времени. Этот график был построен в используемой программное среде с помощью команды
#
# 	make_plot_crd 257 2
#
# применённой к исследуемой молекулярной модели с загруженным файлом сохранённой траектории атомов в процессе моделирования молекулярной динамики
#
# Учитывая периодические граничные условия когда атом мембраны проходит сквозь нижнюю границу ячейки, он появляется обратно в ячейке но сверху, сквозь ее верхнюю границу
#
# То есть график иллюстрирует процесс развития броуновского движения во времени
#
# Как видно из графика, броуновское движение мембраны в атмосфере разреженного газа получило устойчивый тренд

# %% [markdown]
# ![make_plot_crd_257_2.png](images/make_plot_crd_257_2.png)

# %% [markdown]
# В ходе эксперимента мембрана пересекла всю длину ячейки по вертикали 6.5 раз в одном и том же направлении, что свидетельствует о неслучайном характере тренда. Выправляя на графике скачки, связанные с переходом через периодические граничные условия, получаем более наглядный график движения мембраны:

# %% [markdown]
# ![make_plot_crd_continued_257_2.png](images/make_plot_crd_continued_257_2.png)

# %% [markdown]
# Поскольку мембрана не закреплена в данном расчёте, значит она имеет полную свободу перемещаться так же и в горизонтальной плоскости. В связи с этим представляет интерес построить график смещения того же атома, принадлежащего мембране вдоль осей $x$ и $y$:

# %% [markdown]
# ![make_plot_crd_continued_257_0.png](images/make_plot_crd_continued_257_0.png)

# %% [markdown]
# ![make_plot_crd_continued_257_1.png](images/make_plot_crd_continued_257_1.png)

# %% [markdown]
# Как видно из графиков, свободное смещение мембраны в горизонтальном направлении носит характер обычного случайного броуновского движения не имеющего какого либо устойчивого тренда

# %% [markdown]
# Нужно отметить, что это мое первое успешное моделирование ВД2 с момента формулирования мною идеи Синтетического демона Максвелла, опубликованной в журнале "Химия и жизнь", полученное методом молекулярной динамики в чистой молекулярной системе без влияния каких либо внешний сил, наподобие гравитации и иных полей.
#
# В более ранней работе я получал положительный результат при МД моделировании жк двигателя http://liquidcrystalosmos.narod.ru/liquidcrystalengine.htm
# но тогда у меня были неподвижные атомы, которые были зафиксированы, то есть заморожены
#
# Что позволяло получить логичное возражение, что моя система неизотермична
#
# А теперь в моей системе нет ни одного замороженного атома, то есть в данном случае система полностью изотермична

# %% [markdown]
# Можно, однако получить возражение следующего характера: <i>"является ли моделирование доказательством? Эффект может быть из-за особенностей модели. Любой численный метод обладает расчетной вязкостью. То есть нефизической силой, по свойствам аналогичной вязкости. Из-за конечных размеров элементов и конечного числа разрядов. Эта расчетная вязкость и может играть роль запирающего храповика."</i> (Замечание А.Северина)

# %% [markdown]
# Лично я уверен, что дело тут вовсе не в расчетной вязкости. Эффект действительно возникает из-за особенностей модели. Но дело тут именно в том что для разреженного газа вероятность проникновения атома газа сквозь мембрану с коническим отверстием неодинакова для противоположных направлений. Это достаточно убедительно показано Гладких методом простого черчения траектории атома карандашом на бумаге https://www.youtube.com/watch?v=2cJSdVF7Tck
#
# Я проверял доказательтво Гладких используя формулы тригонометрии и вычисляя разность вероятности прохождения атома сквозь клиновидное отверстие в зависимости от геометрических параметров клина. В зависимоти от угла раствора клина, толщины мембраны и ширины отверстия эта разность вероятности может также и поменять знак. Кстати направление дрейфа моей модели мембраны https://github.com/daju1/moldyn/tree/main/conicnanotube.03 противоположно предсказанному Гладких именно из за различия угла раствора моей мембраны и угла клина на рисунке Гладких
#
# В процессе моей дискуссии с Гладких на форуме я сам выдвигал возражение что атомы из которых состоит пора мембраны учавствуют в хаотическом тепловом движении, что предположительно могло нарушить геометрическое доказательство Гладких, полученное на неподвижном клине.
#
# Именно для учета влияния хаотического движения атомов конуса мною и было проведено МД моделирование. Которое показало, что хотя и хаотичность движения атомов приводит к хаотичности характера броуновского движения мембраны, но тем не менее при достаточно продолжительном времени проведения эксперимента (данный эксперимент занял ориентировочно 55 суток машинного времени) было выявлено появление устойчивого во времени неслучайного тренда

# %% [markdown]
# 	trying to open "D:\moldyn\conicnanotube.03\untitled.traj".
# 	 PrintToLog: the trajectory file version 11
# 	 PrintToLog: the trajectory file contains 200000 frames.
# 	 PrintToLog: the trajectory real_frames 67209 does not correspond to 200000 frames. Will be reset

# %% [markdown]
# Промоделированное время, 1.0E-12 сек

# %%
tau_ps = (67209-1) * 5
tau_ps
# Out:
# 336040

# %% [markdown]
# Промоделированное время, нс

# %%
tau_ns = tau_ps / 1000
tau_ns.n()
# Out:
# 336.040000000000

# %% [markdown]
# Расстояние пройденное мембраной за время моделирования, нм

# %%
s = 6.5 * 4
s
# Out:
# 26.0000000000000

# %% [markdown]
# Средняя скорость мембраны, м/сек

# %%
v = s / (tau_ns)
v
# Out:
# 0.0773717414593501

# %% [markdown]
# Средняя скорость мембраны, см/сек

# %%
v * 100
# Out:
# 7.73717414593501

# %% [markdown]
# Итак, по результатам моделирования средняя скорость направленного движения мембраны 7.73 сантиметра в секунду!

# %% [markdown]
# Теперь нужно оценить плотность газа. Исходя из визуальной оценки часть объема ячейки занятая мембраной и не доступная атомам газа составляет ориентировочно

# %%
membrane_part = (1/3*2/3).n()
membrane_part
# Out:
# 0.222222222222222

# %% [markdown]
# то есть 22 процента. Таким образом обьем, занятый газом составляет, куб. нм

# %%
vol_gas_nm3 = vol * (1-membrane_part)
vol_gas_nm3
# Out:
# 8.64840533483733

# %% [markdown]
# концентрация частиц газа, шт в куб. нм

# %%
n_gas_nm3 = 14/vol_gas_nm3
n_gas_nm3
# Out:
# 1.61879554183307

# %% [markdown]
# концентрация частиц газа, шт в куб. м

# %%
n_gas_m3 = 10^27*n_gas_nm3
n_gas_m3
# Out:
# 1.61879554183307e27

# %% [markdown]
# универсальная газовая постоянная = 8.31446262 $Дж\, К^{-1} Моль^{-1}$
#
# $N_A$ ≡ 6,022 140 76 10^23 $моль^{−1}$

# %%
R   = 8.31446262
N_A = 6.02214076 * 10^23
T   = 300

# %% [markdown]
# концентрация газа, моль в куб. м

# %%
c_gas_mol_m3 = n_gas_m3/N_A
c_gas_mol_m3
# Out:
# 2688.07323898066

# %% [markdown]
# Давление газа, Па

# %%
p_Pa = c_gas_mol_m3 * R * T
p_Pa
# Out:
# 6.70496533959812e6

# %%
Pa_per_atm = 98066.5

# %%
p_atm = p_Pa / Pa_per_atm
p_atm
# Out:
# 68.3716186424326

# %% [markdown]
# Итак давление газа в исследованной модели составляет 68.6 атмосфер. Получается диод для молекул с наноразмерными коническими порами работает так же и в области весьма сжатых газов

# %%
#gas_atom_went_down_out_from_membrane 130683
#gas_atom_went_up_into_memrane        131853

#gas_atom_went_down_into_membrane     113814
#gas_atom_went_up_out_from_memrane    113630

# %% [markdown]
# # Дальнейшие исследования
#
# Были произведены дополнительные патчи к программе позволяющие сохранять в файл траектории в процессе моделирования не только координаты каждого атома на определённом шаге моделирования но также скорости, ускорения и силы, приложенные к каждому атому.
#
# Кроме того была разработана команда
#
#     make_plot_mol_crd
#
# позволяющая строить графики координат, скоростей, ускорений и сил, приложенных не к отдельному атому, а к сумме всех атомов в составе мембраны и к сумме всех атомов в составе газа
#
#
# Здесь нужно привести внутрипрограммные единицы измерения
#
# 	f64 * vel;			// [1.0e+3 m/s]
# 	f64 * acc;			// [1.0e+12 m/s^2]
#
# 	f64 * mass;			// [kg/mol]
#
# и внутри программные расчётные формулы молекулярной кинетики
#
# 	tstep1 = 0.5;						// [1.0e-15 s]
# 	tstep2 = tstep1 * tstep1;			// [1.0e-30 s^2]
#
#     f64 tmp1 = tstep1 * vel[n1 * 3 + n2] * 1.0e-3;
#     f64 tmp2 = tstep2 * acc * 0.5e-9;
#
#     eng->crd[n1 * 3 + n2] += tmp1 + tmp2;
#     vel[n1 * 3 + n2] += tstep1 * acc * 0.5e-6;
#
#     acc[n1 * 3 + 0] = -eng->d1[n1 * 3 + 0] / mass[n1];
#     acc[n1 * 3 + 1] = -eng->d1[n1 * 3 + 1] / mass[n1];
#     acc[n1 * 3 + 2] = -eng->d1[n1 * 3 + 2] / mass[n1];
#
#     vel[n1 * 3 + 0] += tstep1 * acc[n1 * 3 + 0] * 0.5e-6;
#     vel[n1 * 3 + 1] += tstep1 * acc[n1 * 3 + 1] * 0.5e-6;
#     vel[n1 * 3 + 2] += tstep1 * acc[n1 * 3 + 2] * 0.5e-6;
#
# Анализируя внутрипрограммные формулы можно заметить, что второй закон Ньютона записан в виде $F = -\,m \cdot a$. Подставляя использованные в программе единицы измерения
#
# $[F] = [kg/mol] \cdot [1.0e+12\,m/s^2]$
#
# $[F] = [1.0e+12\,Newton/mol]$
#
# $[F] = [1.66053906717385e-12\,Newton/atom]$

# %% [markdown]
# Коеффициент перевода единиц силы из внутрипрограмных единиц в Ньютон на атом

# %%
F_ed_izm_N_atom = 1.0e+12/N_A
F_ed_izm_N_atom
# Out:
# 1.66053906717385e-12

# %% [markdown]
# площадь сечения xy ячейки моделирования, кв.м

# %%
s = xyz[0]*xyz[1]*(10^-9)^2
s
# Out:
# 2.77984457191200e-18

# %% [markdown]
# Коэффициент перевода единиц силы из внутрипрограмных единиц в Паскаль на атом

# %%
p_ed_izm_N_atom = F_ed_izm_N_atom / s
p_ed_izm_N_atom
# Out:
# 597349.608662370

# %% [markdown]
# Проблемный файл траектории: средняя скорость мембраны и направление перемещения мембраны имеют разные знаки, что не логично. Здесь был использован интервал между сохраняемыми фреймами 10000 итераций по 0,5 фс каждая

# %% [markdown]
#     DEBUG : trying to open "/usr3/moldyn/conicnanotube.03/conicnanotube.03.traj_v14".
#     PrintToLog: the trajectory file version 14
#
#     PrintToLog: the trajectory file contains 200000 frames.
#
#     PrintToLog: the trajectory real_frames 221 does not correspond to 200000 frames. Will be reset
#
#     PrintToLog: time step between traj records 5 * 1.0E-12 s
#     the trajectory common time is 1.1 * 1.0E-9 s
#
#     PrintToLog: Processing Command : make_plot_mol_crd 1 0 2 0
#
#     boundary 0.836866 0.830433 2.000000
#     loop 220 dc -1.524211e-03 = -6.865742e-06 (-6.876439e-06 + 1.069661e-08) error=-1.517346e-03 1.311839e-02
#
#     sum_d_coordinate_error / sum_coordinate 1.043389
#     sum_coordinate - sum_d_coordinate_error 0.014744
#     sum_coordinate  -0.339806
#     mean_coordinate -1.537584e-03
#     sum_d_coordinate_error  -0.354550
#     mean_d_coordinate_error -1.604298e-03
#     sum_velocity  0.082054
#     mean_velocity 3.712861e-04  [1.0e+3 m/s]
#     mean_coordinate_per_time -3.075168e-07
#     sum_d_velocity_error  -0.000933
#     mean_d_velocity_error -4.221429e-06
#     sum_acceleration  639.416752
#     mean_acceleration 2.893288
#     sum_force -2058.253859
#     mean_force -9.313366

# %% [markdown]
# В следующем эксперименте был уменьшен интервал между сохраняемыми фреймами с 10000 до 1000 итераций

# %% [markdown]
#     DEBUG : trying to open "/usr3/moldyn/conicnanotube.03/test.traj_v14".
#     PrintToLog: the trajectory file version 14
#
#     PrintToLog: the trajectory file contains 2000 frames.
#
#     PrintToLog: the trajectory real_frames 216 does not correspond to 2000 frames. Will be reset
#
#     PrintToLog: time step between traj records 0.5 * 1.0E-12 s
#     the trajectory common time is 0.1075 * 1.0E-9 s
#
#     PrintToLog: Processing Command : make_plor_mol_crd 1 0 2 0
#
#     PrintToLog: ERROR : Unknown command : make_plor_mol_crd 1 0 2 0
#     The "help" command will give more information about command strings.
#
# Команда на построение графика усреднённых координат атомов мембраны
#
#     PrintToLog: Processing Command : make_plot_mol_crd 1 0 2 0
#
#
#     molgroups size = 2
#     gas natoms size = 14
#     membrane or globule natoms size = 268
#
#     boundary 0.830556 0.837337 2.000000
#     loop 1 dc -8.682179e-03 = -8.035715e-06 (-8.029907e-06 + -5.807229e-09) error=-8.674143e-03 -1.512143e-03
#     boundary 0.830329 0.832174 2.000000
#
#     boundary 0.838187 0.826347 2.000000
#     loop 215 dc -1.001905e-02 = -8.583676e-06 (-8.582867e-06 + -8.089961e-10) error=-1.001046e-02 -6.721528e-03
#
#     sum_d_coordinate_error / sum_coordinate 1.402425
#     sum_coordinate - sum_d_coordinate_error 0.014688
#     sum_coordinate  -0.036499
#     mean_coordinate -1.689780e-04
#     sum_d_coordinate_error  -0.051187
#     mean_d_coordinate_error -2.369790e-04
#     sum_velocity  -0.051889
#     mean_velocity -2.402256e-04  [1.0e+3 m/s]
#     mean_coordinate_per_time -3.379560e-07
#     sum_d_velocity_error  -0.023598
#     mean_d_velocity_error -1.092486e-04
#     sum_acceleration  -585.058823
#     mean_acceleration -2.708606
#     sum_force 1883.275572
#     mean_force 8.718868
#
# Команда на построение графика усреднённых координат атомов газа
#
#     PrintToLog: Processing Command : make_plot_mol_crd 0 0 2 0
#
#
#     molgroups size = 2
#     gas natoms size = 14
#     membrane or globule natoms size = 268
#
#
#     boundary 0.836918 0.832544 2.000000
#     loop 1 dc -1.867921e-01 = 9.155651e-05 (9.149035e-05 + 6.616592e-08) error=-1.868837e-01 1.722889e-02
#
#     boundary 0.830415 0.831390 2.000000
#     coordinate -2.056904e+00 - previouse_coordinate 1.902198 < boundary[dim] 2.000000e+00 shift -2
#     loop 214 dc -3.959101e+00 = 2.935901e-05 (2.935966e-05 + -6.580947e-10) error=-3.959131e+00 1.368448e-01
#     boundary 0.838187 0.826347 2.000000
#     loop 215 dc 1.141540e-01 = 9.779982e-05 (9.779061e-05 + 9.217611e-09) error=1.140562e-01 7.658305e-02
#
#     sum_d_coordinate_error / sum_coordinate 4.402881
#     sum_coordinate - sum_d_coordinate_error 1.501628
#     sum_coordinate  -0.441281
#     mean_coordinate -2.042970e-03
#     sum_d_coordinate_error  -1.942910
#     mean_d_coordinate_error -8.994953e-03
#     sum_velocity  0.591204
#     mean_velocity 2.737058e-03  [1.0e+3 m/s]
#     mean_coordinate_per_time -4.085939e-06
#     sum_d_velocity_error  0.268865
#     mean_d_velocity_error 1.244746e-03
#     sum_acceleration  6665.962725
#     mean_acceleration 30.860939
#     sum_force -1883.267881
#     mean_force -8.718833

# %% [markdown]
# Ниже использовалась новая 15 версия файла траектории отличающяяся тем что координаты, скорости, ускорения и силы приложенные к атомам здесь сохраняются в 64 битном формате, а не в 32 битном как это было в более ранних версиях файла траектории

# %% [markdown]
#     DEBUG : trying to open "/usr3/moldyn/conicnanotube.03/test.traj_v15".
#     PrintToLog: the trajectory file version 15
#
#     PrintToLog: the trajectory file contains 2000 frames.
#
#     PrintToLog: the trajectory real_frames 219 does not correspond to 2000 frames. Will be reset
#
#     PrintToLog: time step between traj records 0.5 * 1.0E-12 s
#     the trajectory common time is 0.109 * 1.0E-9 s
#
# Команда на построение графика усреднённых координат атомов мембраны
#
#     PrintToLog: Processing Command : make_plot_mol_crd 1 0 2 0
#
#
#     sum_d_coordinate_error / sum_coordinate 1.262427
#     sum_coordinate - sum_d_coordinate_error 0.014668
#     sum_coordinate  -0.055892
#     mean_coordinate -2.552135e-04
#     sum_d_coordinate_error  -0.070559
#     mean_d_coordinate_error -3.221885e-04
#     sum_velocity  -0.079649
#     mean_velocity -3.636959e-04  [1.0e+3 m/s]
#     mean_coordinate_per_time -5.104270e-07
#     sum_d_velocity_error  -0.009966
#     mean_d_velocity_error -4.550564e-05
#     sum_acceleration  -549.629861
#     mean_acceleration -2.509725
#     sum_force 1769.229910
#     mean_force 8.078675
#
# Команда на построение графика усреднённых координат атомов газа
#
#     PrintToLog: Processing Command : make_plot_mol_crd 0 0 2 0
#
#     sum_d_coordinate_error / sum_coordinate -21.969442
#     sum_coordinate - sum_d_coordinate_error 1.501864
#     sum_coordinate  0.065385
#     mean_coordinate 2.985631e-04
#     sum_d_coordinate_error  -1.436479
#     mean_d_coordinate_error -6.559265e-03
#     sum_velocity  0.907501
#     mean_velocity 4.143842e-03  [1.0e+3 m/s]
#     mean_coordinate_per_time 5.971262e-07
#     sum_d_velocity_error  0.113547
#     mean_d_velocity_error 5.184776e-04
#     sum_acceleration  6262.317247
#     mean_acceleration 28.595056
#     sum_force -1769.229910
#     mean_force -8.078675

# %% [markdown]
#     DEBUG : trying to open "/usr3/moldyn/conicnanotube.03/first_frame_B0_E.traj_v17".
#     PrintToLog: the trajectory file version 17
#
#     PrintToLog: the trajectory file contains 2000000 frames.
#
#     PrintToLog: the trajectory real_frames 22776 does not correspond to 2000000 frames. Will be reset
#
#     PrintToLog: traj_frame_save_frq 1000 traj_tstep1 0.5
#     time step between traj records 0.5 * 1.0E-12 s
#     the trajectory common time is 11.3875 * 1.0E-9 s
#
#
# Команда на построение графика усреднённых координат атомов мембраны
#
#     PrintToLog: Processing Command : make_plot_mol_crd 1 0 2 0
#
#
#     molgroups size = 2
#     gas natoms size = 14
#     membrane or globule natoms size = 268
#     boundary 0.831378 0.832443 2.000000
#     loop 22775 dc -3.643084e-03 = -8.542966e-06 (-8.542461e-06 + -5.047581e-10) error=-3.634541e-03 1.728350e-02
#     sum_d_coordinate_error / sum_coordinate 1.008453
#     sum_coordinate - sum_d_coordinate_error 0.005143
#     sum_coordinate  -0.608391 (nm)
#     mean_coordinate -2.671193e-05 (nm/frame)
#     sum_d_coordinate_error  -0.613534
#     mean_d_coordinate_error -2.693772e-05
#     sum_velocity  -1.407110
#     mean_velocity -6.178037e-05 [1.0e+3 m/s]
#     mean_coordinate_per_time -5.342386e-08 [nm/fs]
#     sum_d_velocity_error  0.000320
#     mean_d_velocity_error 1.404097e-08
#     sum_acceleration  -247.296388
#     mean_acceleration -0.010858
#     sum_force 796.034199
#     mean_force 0.034951
#
#     gas_atom_went_down_out_from_membrane 12511
#     gas_atom_went_up_into_memrane        12531
#     gas_atom_went_down_into_membrane      8643
#     gas_atom_went_up_out_from_memrane     8662

# %% [markdown]
# ![first_frame_B0_E_plot_mol_crd.png](attachment:first_frame_B0_E_plot_mol_crd.png)

# %% [markdown]
# Давление на мембране, Паскаль

# %%
p_os = 0.034951 * p_ed_izm_N_atom
p_os
# Out:
# 20877.9661723585

# %% [markdown]
# Давление на мембране, атм

# %%
p_os / Pa_per_atm
# Out:
# 0.212896005999587

# %% [markdown]
# $V_{ос}$ — осмотический поток растворителя, $м/с$;

# %%
V_os = 6.178037e-05 * 1.0e+3
V_os
# Out:
# 0.0617803700000000

# %% [markdown]
# удельная мощность (мощность на единицу площади мембраны) осмотического двигателя.
#
# $w = \eta  \cdot p \cdot V_{ос}\,\,\,\frac{Вт}{м^2}$

# %%
0.5 * p_os * V_os
# Out:
# 644.924237487896

# %% [markdown]
#     DEBUG : trying to open "/usr3/moldyn/conicnanotube.03/first_frame_B0_E_I.traj_v17".
#     PrintToLog: the trajectory file version 17
#
#     PrintToLog: the trajectory file contains 2000000 frames.
#
#     PrintToLog: the trajectory real_frames 22926 does not correspond to 2000000 frames. Will be reset
#
#     PrintToLog: traj_frame_save_frq 1000 traj_tstep1 0.5
#     time step between traj records 0.5 * 1.0E-12 s
#     the trajectory common time is 11.4625 * 1.0E-9 s
#
#
#     PrintToLog: Processing Command : make_plot_mol_crd 1 0 2 0
#
#
#     molgroups size = 2
#     gas natoms size = 14
#     membrane or globule natoms size = 268
#     boundary 0.831378 0.832443 2.000000
#     loop 22925 dc 4.423323e-03 = 4.637595e-06 (4.637249e-06 + 3.457860e-10) error=4.418685e-03 -3.735328e-03
#     sum_d_coordinate_error / sum_coordinate 1.003389
#     sum_coordinate - sum_d_coordinate_error 0.004458
#     sum_coordinate  -1.315563 (nm)
#     mean_coordinate -5.738304e-05 (nm/frame)
#     sum_d_coordinate_error  -1.320022
#     mean_d_coordinate_error -5.757750e-05
#     sum_velocity  -2.771601
#     mean_velocity -1.208933e-04 [1.0e+3 m/s]
#     mean_coordinate_per_time -1.147661e-07 [nm/fs]
#     sum_d_velocity_error  0.002794
#     mean_d_velocity_error 1.218548e-07
#     sum_acceleration  5452.736827
#     mean_acceleration 0.237841
#     sum_force -17552.075975
#     mean_force -0.765597
#
#     gas_atom_went_down_out_from_membrane 12103
#     gas_atom_went_up_into_memrane        12139
#     gas_atom_went_down_into_membrane      9091
#     gas_atom_went_up_out_from_memrane     9098

# %% [markdown]
# ![first_frame_B0_E_I_plot_mol_crd.png](attachment:first_frame_B0_E_I_plot_mol_crd.png)

# %% [markdown]
# # Сравнение результатов работы МД с разными опциями алгоритма

# %% [markdown]
# first_frame - сохраняем фреймы в траекторию с самого начала
#
# B0, B1, B2 в названии файла означает режим оптимизации размера бокса во время процесса МД
#
# B0 - отсутствует оптимизация размера бокса вообще
#
# B1 - оптимизация размера бокса включена постоянно. Этот режим также был включён по умолчанию ранее в предыдущих моделированиях а также в файлах тракторий с отсутствующей буквой B
#
# B2 - только лишь в процессе нагревания и уравновешивания
#
# enum box_optimization_moldyn_mode
# {
# 	box_optimization_no = 0,
# 	box_optimization_always,
# 	box_optimization_equilibration, // box_optimization just during heating and equilibration
# };
#
# E - алгоритм термостата выключен, моделирование при постоянной энергии
#
# I - инверсия скоростей инициализации начальных скоростей атомов

# %% [markdown]
#     trying to open "I:\moldyn\conicnanotube.03\first_frame.traj_v17".
#      PrintToLog: the trajectory file version 17
#      PrintToLog: the trajectory file contains 2000000 frames.
#      PrintToLog: the trajectory real_frames 16917 does not correspond to 2000000 frames. Will be reset
#      PrintToLog: traj_frame_save_frq 1000 traj_tstep1 0.5
#     time step between traj records 0.5 * 1.0E-12 s
#     the trajectory common time is 8.458 * 1.0E-9 s
#      PrintToLog: Processing Command : make_plot_mol_crd 1 0 2 0
#
#     molgroups size = 2
#     gas natoms size = 14
#     membrane or globule natoms size = 268
#     boundary 0.837428 0.831987 2.000000
#     loop 16916 dc -1.193480e-002 = -1.268120e-005 (-1.268244e-005 + 1.246361e-009) error=-1.192212e-002 2.496284e-003
#     sum_d_coordinate_error / sum_coordinate 0.975062
#     sum_coordinate - sum_d_coordinate_error 0.006052
#     sum_coordinate  0.242688 (nm)
#     mean_coordinate 1.434579e-005 (nm/frame)
#     sum_d_coordinate_error  0.236636
#     mean_d_coordinate_error 1.398804e-005
#     sum_velocity  0.390472
#     mean_velocity 2.308165e-005 [1.0e+3 m/s]
#     mean_coordinate_per_time 2.869159e-008 [nm/fs]
#     sum_coordinate_per_time 2.869328e-002 [m/s]
#     sum_d_velocity_error  -0.019894
#     mean_d_velocity_error -1.175994e-006
#     sum_acceleration  -5935.982752
#     mean_acceleration -0.350889
#     sum_force 19107.619451
#     mean_force 1.129492
#     gas_atom_went_down_out_from_membrane 7350
#     gas_atom_went_up_into_memrane 7361
#     gas_atom_went_down_into_membrane 2230
#     gas_atom_went_up_out_from_memrane 2202

# %% [markdown]
# ![first_frame_plot_mol_crd_win.png](attachment:first_frame_plot_mol_crd_win.png)

# %% [markdown]
#      PrintToLog: Processing Command : make_plot_mol_crd 1 0 2 0
#     trying to open "I:\moldyn\conicnanotube.03\first_frame_I.traj_v17".
#      PrintToLog: the trajectory file version 17
#      PrintToLog: the trajectory file contains 2000000 frames.
#      PrintToLog: the trajectory real_frames 17095 does not correspond to 2000000 frames. Will be reset
#      PrintToLog: traj_frame_save_frq 1000 traj_tstep1 0.5
#     time step between traj records 0.5 * 1.0E-12 s
#     the trajectory common time is 8.547 * 1.0E-9 s
#      PrintToLog: Processing Command : make_plot_mol_crd 1 0 2 0
#     molgroups size = 2
#     gas natoms size = 14
#     membrane or globule natoms size = 268
#     boundary 0.834087 0.836892 2.000000
#     loop 17094 dc 6.163564e-003 = 6.822247e-006 (6.823202e-006 + -9.546184e-010) error=6.156742e-003 -2.685692e-003
#     sum_d_coordinate_error / sum_coordinate 1.001082
#     sum_coordinate - sum_d_coordinate_error 0.003142
#     sum_coordinate  -2.903520 (nm)
#     mean_coordinate -1.698461e-004 (nm/frame)
#     sum_d_coordinate_error  -2.906662
#     mean_d_coordinate_error -1.700299e-004
#     sum_velocity  -5.396125
#     mean_velocity -3.156551e-004 [1.0e+3 m/s]
#     mean_coordinate_per_time -3.396923e-007 [nm/fs]
#     sum_coordinate_per_time -3.397121e-001 [m/s]
#     sum_d_velocity_error  0.012307
#     mean_d_velocity_error 7.199111e-007
#     sum_acceleration  -2700.143904
#     mean_acceleration -0.157949
#     sum_force 8691.622658
#     mean_force 0.508431
#     gas_atom_went_down_out_from_membrane 6931
#     gas_atom_went_up_into_memrane 7032
#     gas_atom_went_down_into_membrane 2208
#     gas_atom_went_up_out_from_memrane 2321

# %% [markdown]
# ![first_frame_I_plot_mol_crd_win.png](attachment:first_frame_I_plot_mol_crd_win.png)

# %% [markdown]
#     trying to open "I:\moldyn\conicnanotube.03\first_frame_B0.traj_v17".
#      PrintToLog: the trajectory file version 17
#      PrintToLog: the trajectory file contains 2000000 frames.
#      PrintToLog: the trajectory real_frames 23078 does not correspond to 2000000 frames. Will be reset
#      PrintToLog: traj_frame_save_frq 1000 traj_tstep1 0.5
#     time step between traj records 0.5 * 1.0E-12 s
#     the trajectory common time is 11.5385 * 1.0E-9 s
#      PrintToLog: Processing Command : make_plot_mol_crd 1 0 2 0
#     molgroups size = 2
#     gas natoms size = 14
#     membrane or globule natoms size = 268
#     boundary 0.831378 0.832443 2.000000
#     loop 23077 dc 4.349200e-003 = 2.724610e-006 (2.724232e-006 + 3.778805e-010) error=4.346476e-003 -3.135192e-003
#     sum_d_coordinate_error / sum_coordinate 1.017186
#     sum_coordinate - sum_d_coordinate_error 0.005477
#     sum_coordinate  -0.318690 (nm)
#     mean_coordinate -1.380924e-005 (nm/frame)
#     sum_d_coordinate_error  -0.324167
#     mean_d_coordinate_error -1.404656e-005
#     sum_velocity  -0.736216
#     mean_velocity -3.190119e-005 [1.0e+3 m/s]
#     mean_coordinate_per_time -2.761848e-008 [nm/fs]
#     sum_coordinate_per_time -2.761967e-002 [m/s]
#     sum_d_velocity_error  0.002487
#     mean_d_velocity_error 1.077805e-007
#     sum_acceleration  -365.868351
#     mean_acceleration -0.015854
#     sum_force 1177.711174
#     mean_force 0.051032
#     gas_atom_went_down_out_from_membrane 6303
#     gas_atom_went_up_into_memrane 6337
#     gas_atom_went_down_into_membrane 2197
#     gas_atom_went_up_out_from_memrane 2218

# %% [markdown]
# ![first_frame_B0_plot_mol_crd_win.png](attachment:first_frame_B0_plot_mol_crd_win.png)

# %% [markdown]
#     trying to open "I:\moldyn\conicnanotube.03\first_frame_B0_I.traj_v17".
#      PrintToLog: the trajectory file version 17
#      PrintToLog: the trajectory file contains 2000000 frames.
#      PrintToLog: the trajectory real_frames 23088 does not correspond to 2000000 frames. Will be reset
#      PrintToLog: traj_frame_save_frq 1000 traj_tstep1 0.5
#     time step between traj records 0.5 * 1.0E-12 s
#     the trajectory common time is 11.5435 * 1.0E-9 s
#      PrintToLog: Processing Command : make_plot_mol_crd 1 0 2 0
#     molgroups size = 2
#     gas natoms size = 14
#     membrane or globule natoms size = 268
#     boundary 0.831378 0.832443 2.000000
#     loop 23087 dc -3.956655e-003 = 2.310002e-007 (2.299128e-007 + 1.087413e-009) error=-3.956886e-003 -1.556886e-002
#     sum_d_coordinate_error / sum_coordinate 1.022422
#     sum_coordinate - sum_d_coordinate_error 0.005600
#     sum_coordinate  -0.249763 (nm)
#     mean_coordinate -1.081788e-005 (nm/frame)
#     sum_d_coordinate_error  -0.255364
#     mean_d_coordinate_error -1.106044e-005
#     sum_velocity  -0.508683
#     mean_velocity -2.203235e-005 [1.0e+3 m/s]
#     mean_coordinate_per_time -2.163577e-008 [nm/fs]
#     sum_coordinate_per_time -2.163671e-002 [m/s]
#     sum_d_velocity_error  -0.018010
#     mean_d_velocity_error -7.800767e-007
#     sum_acceleration  5850.304330
#     mean_acceleration 0.253392
#     sum_force -18831.825073
#     mean_force -0.815654
#     gas_atom_went_down_out_from_membrane 6477
#     gas_atom_went_up_into_memrane 6459
#     gas_atom_went_down_into_membrane 2276
#     gas_atom_went_up_out_from_memrane 2251

# %% [markdown]
# ![first_frame_B0_I_plot_mol_crd_win.png](attachment:first_frame_B0_I_plot_mol_crd_win.png)

# %% [markdown]
#     trying to open "I:\moldyn\conicnanotube.03\first_frame_B0_E.traj_v17".
#      PrintToLog: the trajectory file version 17
#      PrintToLog: the trajectory file contains 2000000 frames.
#      PrintToLog: the trajectory real_frames 22776 does not correspond to 2000000 frames. Will be reset
#      PrintToLog: traj_frame_save_frq 1000 traj_tstep1 0.5
#     time step between traj records 0.5 * 1.0E-12 s
#     the trajectory common time is 11.3875 * 1.0E-9 s
#      PrintToLog: Processing Command : make_plot_mol_crd 1 0 2 0
#     molgroups size = 2
#     gas natoms size = 14
#     membrane or globule natoms size = 268
#     boundary 0.831378 0.832443 2.000000
#     loop 22775 dc -3.643084e-003 = -8.542966e-006 (-8.542461e-006 + -5.047581e-010) error=-3.634541e-003 1.728350e-002
#     sum_d_coordinate_error / sum_coordinate 1.008453
#     sum_coordinate - sum_d_coordinate_error 0.005143
#     sum_coordinate  -0.608391 (nm)
#     mean_coordinate -2.671193e-005 (nm/frame)
#     sum_d_coordinate_error  -0.613534
#     mean_d_coordinate_error -2.693772e-005
#     sum_velocity  -1.407110
#     mean_velocity -6.178037e-005 [1.0e+3 m/s]
#     mean_coordinate_per_time -5.342386e-008 [nm/fs]
#     sum_coordinate_per_time -5.342621e-002 [m/s]
#     sum_d_velocity_error  0.000320
#     mean_d_velocity_error 1.404097e-008
#     sum_acceleration  -247.296388
#     mean_acceleration -0.010858
#     sum_force 796.034199
#     mean_force 0.034951
#     gas_atom_went_down_out_from_membrane 5887
#     gas_atom_went_up_into_memrane 5930
#     gas_atom_went_down_into_membrane 2019
#     gas_atom_went_up_out_from_memrane 2061

# %% [markdown]
# ![first_frame_B0_E_plot_mol_crd_win.png](attachment:first_frame_B0_E_plot_mol_crd_win.png)

# %% [markdown]
#     trying to open "I:\moldyn\conicnanotube.03\first_frame_B0_E_I.traj_v17".
#      PrintToLog: the trajectory file version 17
#      PrintToLog: the trajectory file contains 2000000 frames.
#      PrintToLog: the trajectory real_frames 22926 does not correspond to 2000000 frames. Will be reset
#      PrintToLog: traj_frame_save_frq 1000 traj_tstep1 0.5
#     time step between traj records 0.5 * 1.0E-12 s
#     the trajectory common time is 11.4625 * 1.0E-9 s
#      PrintToLog: Processing Command : make_plot_mol_crd 1 0 2 0
#     molgroups size = 2
#     gas natoms size = 14
#     membrane or globule natoms size = 268
#     boundary 0.831378 0.832443 2.000000
#     loop 22925 dc 4.423323e-003 = 4.637595e-006 (4.637249e-006 + 3.457860e-010) error=4.418685e-003 -3.735328e-003
#     sum_d_coordinate_error / sum_coordinate 1.003389
#     sum_coordinate - sum_d_coordinate_error 0.004458
#     sum_coordinate  -1.315563 (nm)
#     mean_coordinate -5.738304e-005 (nm/frame)
#     sum_d_coordinate_error  -1.320022
#     mean_d_coordinate_error -5.757750e-005
#     sum_velocity  -2.771601
#     mean_velocity -1.208933e-004 [1.0e+3 m/s]
#     mean_coordinate_per_time -1.147661e-007 [nm/fs]
#     sum_coordinate_per_time -1.147711e-001 [m/s]
#     sum_d_velocity_error  0.002794
#     mean_d_velocity_error 1.218548e-007
#     sum_acceleration  5452.736827
#     mean_acceleration 0.237841
#     sum_force -17552.075975
#     mean_force -0.765597
#     gas_atom_went_down_out_from_membrane 5547
#     gas_atom_went_up_into_memrane 5622
#     gas_atom_went_down_into_membrane 2048
#     gas_atom_went_up_out_from_memrane 2109

# %% [markdown]
# ![first_frame_B0_E_I_plot_mol_crd_win.png](attachment:first_frame_B0_E_I_plot_mol_crd_win.png)

# %% [markdown]
#     trying to open "I:\moldyn\conicnanotube.03\first_frame_B2.traj_v17".
#      PrintToLog: the trajectory file version 17
#      PrintToLog: the trajectory file contains 2000000 frames.
#      PrintToLog: the trajectory real_frames 23122 does not correspond to 2000000 frames. Will be reset
#      PrintToLog: traj_frame_save_frq 1000 traj_tstep1 0.5
#     time step between traj records 0.5 * 1.0E-12 s
#     the trajectory common time is 11.5605 * 1.0E-9 s
#      PrintToLog: Processing Command : make_plot_mol_crd 1 0 2 0
#     molgroups size = 2
#     gas natoms size = 14
#     membrane or globule natoms size = 268
#     boundary 0.836424 0.838767 2.000000
#     loop 23121 dc -7.189380e-003 = -8.505595e-006 (-8.505411e-006 + -1.834342e-010) error=-7.180874e-003 5.405464e-003
#     sum_d_coordinate_error / sum_coordinate 0.978332
#     sum_coordinate - sum_d_coordinate_error 0.006082
#     sum_coordinate  0.280677 (nm)
#     mean_coordinate 1.213897e-005 (nm/frame)
#     sum_d_coordinate_error  0.274596
#     mean_d_coordinate_error 1.187594e-005
#     sum_velocity  0.458854
#     mean_velocity 1.984489e-005 [1.0e+3 m/s]
#     mean_coordinate_per_time 2.427793e-008 [nm/fs]
#     sum_coordinate_per_time 2.427898e-002 [m/s]
#     sum_d_velocity_error  -0.012180
#     mean_d_velocity_error -5.267921e-007
#     sum_acceleration  1143.855013
#     mean_acceleration 0.049470
#     sum_force -3682.009736
#     mean_force -0.159243
#     gas_atom_went_down_out_from_membrane 6498
#     gas_atom_went_up_into_memrane 6492
#     gas_atom_went_down_into_membrane 2107
#     gas_atom_went_up_out_from_memrane 2089

# %% [markdown]
# ![first_frame_B2_plot_mol_crd_win.png](attachment:first_frame_B2_plot_mol_crd_win.png)

# %% [markdown]
#     trying to open "I:\moldyn\conicnanotube.03\first_frame_B2_I.traj_v17".
#      PrintToLog: the trajectory file version 17
#      PrintToLog: the trajectory file contains 2000000 frames.
#      PrintToLog: the trajectory real_frames 23012 does not correspond to 2000000 frames. Will be reset
#      PrintToLog: traj_frame_save_frq 1000 traj_tstep1 0.5
#     time step between traj records 0.5 * 1.0E-12 s
#     the trajectory common time is 11.5055 * 1.0E-9 s
#      PrintToLog: Processing Command : make_plot_mol_crd 1 0 2 0
#     molgroups size = 2
#     gas natoms size = 14
#     membrane or globule natoms size = 268
#     boundary 0.835290 0.834522 2.000000
#     loop 23011 dc -1.835487e-003 = -3.542031e-006 (-3.541668e-006 + -3.629611e-010) error=-1.831945e-003 1.039812e-002
#     sum_d_coordinate_error / sum_coordinate 1.004466
#     sum_coordinate - sum_d_coordinate_error 0.004854
#     sum_coordinate  -1.087022 (nm)
#     mean_coordinate -4.723717e-005 (nm/frame)
#     sum_d_coordinate_error  -1.091876
#     mean_d_coordinate_error -4.744812e-005
#     sum_velocity  -1.980950
#     mean_velocity -8.608333e-005 [1.0e+3 m/s]
#     mean_coordinate_per_time -9.447435e-008 [nm/fs]
#     sum_coordinate_per_time -9.447846e-002 [m/s]
#     sum_d_velocity_error  0.003130
#     mean_d_velocity_error 1.360048e-007
#     sum_acceleration  381.810931
#     mean_acceleration 0.016592
#     sum_force -1229.029510
#     mean_force -0.053408
#     gas_atom_went_down_out_from_membrane 5882
#     gas_atom_went_up_into_memrane 5863
#     gas_atom_went_down_into_membrane 2075
#     gas_atom_went_up_out_from_memrane 2122

# %% [markdown]
# ![first_frame_B2_I_plot_mol_crd_win.png](attachment:first_frame_B2_I_plot_mol_crd_win.png)

# %% [markdown]
#     trying to open "I:\moldyn\conicnanotube.03\first_frame_B2_E.traj_v17".
#      PrintToLog: the trajectory file version 17
#      PrintToLog: the trajectory file contains 2000000 frames.
#      PrintToLog: the trajectory real_frames 23110 does not correspond to 2000000 frames. Will be reset
#      PrintToLog: traj_frame_save_frq 1000 traj_tstep1 0.5
#     time step between traj records 0.5 * 1.0E-12 s
#     the trajectory common time is 11.5545 * 1.0E-9 s
#      PrintToLog: Processing Command : make_plot_mol_crd 1 0 2 0
#     molgroups size = 2
#     gas natoms size = 14
#     membrane or globule natoms size = 268
#     boundary 0.836424 0.838767 2.000000
#     loop 23109 dc 7.420878e-004 = 2.223462e-006 (2.225061e-006 + -1.598477e-009) error=7.398644e-004 -2.936023e-003
#     sum_d_coordinate_error / sum_coordinate 0.990137
#     sum_coordinate - sum_d_coordinate_error 0.006504
#     sum_coordinate  0.659456 (nm)
#     mean_coordinate 2.853552e-005 (nm/frame)
#     sum_d_coordinate_error  0.652952
#     mean_d_coordinate_error 2.825408e-005
#     sum_velocity  1.316556
#     mean_velocity 5.696912e-005 [1.0e+3 m/s]
#     mean_coordinate_per_time 5.707105e-008 [nm/fs]
#     sum_coordinate_per_time 5.707352e-002 [m/s]
#     sum_d_velocity_error  -0.000225
#     mean_d_velocity_error -9.742715e-009
#     sum_acceleration  3532.771652
#     mean_acceleration 0.152868
#     sum_force -11371.808030
#     mean_force -0.492073
#     gas_atom_went_down_out_from_membrane 5962
#     gas_atom_went_up_into_memrane 5986
#     gas_atom_went_down_into_membrane 2043
#     gas_atom_went_up_out_from_memrane 2011

# %% [markdown]
# ![first_frame_B2_E_plot_mol_crd_win.png](attachment:first_frame_B2_E_plot_mol_crd_win.png)

# %% [markdown]
#     trying to open "I:\moldyn\conicnanotube.03\first_frame_B2_E_I.traj_v17".
#      PrintToLog: the trajectory file version 17
#      PrintToLog: the trajectory file contains 2000000 frames.
#      PrintToLog: the trajectory real_frames 23009 does not correspond to 2000000 frames. Will be reset
#      PrintToLog: traj_frame_save_frq 1000 traj_tstep1 0.5
#     time step between traj records 0.5 * 1.0E-12 s
#     the trajectory common time is 11.504 * 1.0E-9 s
#      PrintToLog: Processing Command : make_plot_mol_crd 1 0 2 0
#     molgroups size = 2
#     gas natoms size = 14
#     membrane or globule natoms size = 268
#     boundary 0.835290 0.834522 2.000000
#     loop 23008 dc -2.285566e-003 = 8.567149e-007 (8.597219e-007 + -3.006965e-009) error=-2.286422e-003 -4.428659e-003
#     sum_d_coordinate_error / sum_coordinate 1.007565
#     sum_coordinate - sum_d_coordinate_error 0.005232
#     sum_coordinate  -0.691680 (nm)
#     mean_coordinate -3.006127e-005 (nm/frame)
#     sum_d_coordinate_error  -0.696912
#     mean_d_coordinate_error -3.028868e-005
#     sum_velocity  -1.231064
#     mean_velocity -5.350359e-005 [1.0e+3 m/s]
#     mean_coordinate_per_time -6.012255e-008 [nm/fs]
#     sum_coordinate_per_time -6.012516e-002 [m/s]
#     sum_d_velocity_error  -0.004177
#     mean_d_velocity_error -1.815222e-007
#     sum_acceleration  2932.525467
#     mean_acceleration 0.127451
#     sum_force -9439.646810
#     mean_force -0.410259
#     gas_atom_went_down_out_from_membrane 5957
#     gas_atom_went_up_into_memrane 5989
#     gas_atom_went_down_into_membrane 2014
#     gas_atom_went_up_out_from_memrane 2022

# %% [markdown]
# ![first_frame_B2_E_I_plot_mol_crd_win.png](attachment:first_frame_B2_E_I_plot_mol_crd_win.png)
