# %% [markdown]
# I have a question about kinetic Energy
#
#
# Have you ever seen the following form of the kinetic Energy in MD
#
#
# $T = \sum_{i}^{} \frac{1}{2} m_i \dot{x_i}^2 + \sum_{i}^{} \sum_{j}^{} \frac{1}{2} m_{ij} \left(\vec {\dot{x_i}}, \vec {\dot{x_j}}\right)$

# %% [markdown]
# $m_i$ - self-induction coefficient of the particle (electromagnetic mass)

# %% [markdown]
# $m_{ij}$ - mutual induction coefficient of two particles (electromagnetic cross mass)

# %% [markdown]
# Позаимстовав из И.Е.Тамм. Основы теории электричества. 1957 формулу
#
# потенциальной "энергии" системы двух токов

# %% [markdown]
# $U = -\frac{1}{c^2}\left(\frac{1}{2}L_{11}\,J_{1}^2+L_{12}\,J_{1}\,J_{2}+\frac{1}{2}L_{22}\,J_{2}^2\right). \,\,\,(52.9)$

# %% [markdown]
# $U = -\frac{1}{c^2}\frac{1}{2}\left(L_{11}\,J_{1}^2+L_{12}\,J_{1}\,J_{2}+L_{21}\,J_{2}\,J_{1}+L_{22}\,J_{2}^2\right). \,\,\,(52.10)$

# %% [markdown]
# Если сфера радиуса R, имеющая объем
#
#     V = 4/3 * pi * R^3
#
# с плотностью электрического заряда rho имеет суммарный заряд
#
#     q = rho * V
#
# тогда, если она двигается со скоростью v ее полный ток J можно вычислить по формуле
#
#     J = (rho*v).integrate(dS) -> (mean) -> (rho*v).integrate(dV) / (2*R) = q*v / (2 * R)
#     J = q * v / (2 * R)
#
# Учитывая эту формулу мы можем переписать "потенциальную энергию" (52.10) системы двух движущихся электрически заряженных сфер в следующем виде

# %% [markdown]
# $U = -\frac{1}{c^2}\frac{1}{2}\left(L_{11}\,\left(\frac{q_{1}\,v_1}{2\,R_1}\right)^2+L_{12}\,\left(\frac{q_{1}\,v_1}{2\,R_1}\right)\,\left(\frac{q_{2}\,v_2}{2\,R_2}\right)+L_{21}\,\left(\frac{q_{2}\,v_2}{2\,R_2}\right)\,\left(\frac{q_{1}\,v_1}{2\,R_1}\right)+L_{22}\,\left(\frac{q_{2}\,v_2}{2\,R_2}\right)^2\right). \,\,\,(52.10)$

# %% [markdown]
# легко видеть, что эта формула по своей структуре соответствует формуле кинетической энергии
#
# $T = \sum_{i}^{} \frac{1}{2} m_i \dot{x_i}^2 + \sum_{i}^{} \sum_{j}^{} \frac{1}{2} m_{ij} \left(\vec {\dot{x_i}}, \vec {\dot{x_j}}\right)$
#
# если для масс и для кросс-масс принять следующие выражения

# %% [markdown]
# обычная масса имеет смысл коэффициента самоиндукции
#
# $m_i = \frac{L_{ii}}{c^2}\left(\frac{q_{i}}{2\,R_i}\right)^2=\frac{1}{c^2\,J_i^2}\left(\frac{q_{i}}{2\,R_i}\right)^2\int\limits_{V_i}\int\limits_{V_i}\frac{\left(\vec{j_i},\vec{j'_i}\right)\,dV\,dV'}{r}$

# %% [markdown]
# кросс масса имеет смысл коэффициента взаимоиндукции
#
# $m_{ij} = m_{ji} = \left(\frac{q_{i}\,q_{j}}{4\,R_i\,R_j}\right)\frac{L_{ij}}{c^2} = \frac{q_{i}\,q_{j}}{4\,R_i\,R_j}\frac{L_{ji}}{c^2} = \\
# \left(\frac{q_{i}\,q_{j}}{4\,R_i\,R_j}\right)\frac{1}{c^2\,J_i\,J_j}\int\limits_{V_i}\int\limits_{V_j}\frac{\left(\vec{j_i},\vec{j_j}\right)\,dV_i\,dV_j}{r} = \\
# \left(\frac{q_{i}\,q_{j}}{4\,R_i\,R_j}\right)\frac{1}{c^2\,J_i\,J_j}\int\limits_{V_i}\int\limits_{V_j}\frac{\left(\rho_i\,\vec{v_i},\rho_j\,\vec{v_j}\right)\,dV_i\,dV_j}{r} \approx \frac{q_{i}\,q_{j}}{4\,R_i\,R_j}\frac{1}{c^2\,J_i\,J_j}\,q_i\,q_j\,\frac{\left(\vec{v_i},\vec{v_j}\right)}{r}$

# %% [markdown]
# Учитывая формулу для векторного потенциала
#
# $A_{i} = \frac{1}{c}\int\limits_{V_i}\frac{\vec{j_i}\,dV_i}{r} = \frac{1}{c}\int\limits_{V_i}\frac{\rho_i\vec{v_i}\,dV_i}{r}$

# %% [markdown]
# для кроссмассы имеем также
#
# $m_{ij} = m_{ji} = \frac{q_{i}\,q_{j}}{4\,R_i\,R_j}\frac{L_{ij}}{c^2} = \frac{q_{i}\,q_{j}}{4\,R_i\,R_j}\frac{L_{ji}}{c^2} = \frac{q_{i}\,q_{j}}{4\,R_i\,R_j}\frac{1}{c\,J_i\,J_j}\int\limits_{V_j}{\left(\vec{A_i},\vec{j_j}\right)\,dV_i\,dV_j}$

# %% [markdown]
# В данной работе для кроссмассы примем приблизительное значение
#
# $m_{ij} \approx \frac{q_{i}\,q_{j}}{4\,R_i\,R_j}\frac{1}{c^2\,J_i\,J_j}\,q_i\,q_j\,\frac{\left(\vec{v_i},\vec{v_j}\right)}{r} = \frac{q_{i}\,q_{j}}{4\,R_i\,R_j}\frac{2\,R_i\,2\,R_j}{c^2\,q_i\,v_i\,q_j\,v_j}\,q_i\,q_j\,\frac{\left(\vec{v_i},\vec{v_j}\right)}{r} = \frac{q_{i}\,q_{j}}{c^2}\,\frac{cos\left(\vec{v_i},\vec{v_j}\right)}{r}$

# %% [markdown]
# Запишем Лагранжиан
#
# $L = T - V$

# %% [markdown]
# $L = \sum_{i}^{} \frac{1}{2} m_i \dot{x_i}^2 + \sum_{i}^{} \sum_{j}^{} \frac{1}{2} m_{ij} \dot{x_i} \dot{x_j} - V(x)$

# %% [markdown]
# $L = \sum_{i}^{} \frac{1}{2} m_i \dot{x_i}^2 + \sum_{i}^{} \sum_{j}^{} \frac{1}{2} \frac{q_{i}\,q_{j}}{c^2}\,\frac{cos\left(\vec{\dot{x_i}},\vec{\dot{x_j}}\right)}{r} \dot{x_i} \dot{x_j} - V(r)$

# %% [markdown]
# $L = \sum_{i}^{} \frac{1}{2} m_i \dot{x_i}^2 + \sum_{i}^{} \sum_{j}^{} \frac{1}{2} \frac{q_{i}\,q_{j}}{c^2}\,\frac{\left(\vec{\dot{x_i}},\vec{\dot{x_j}}\right)}{r} - V(r)$

# %% [markdown]
# $L = \sum_{i}^{} \frac{1}{2} m_i \left(\dot{x_i}^2+\dot{y_i}^2+\dot{z_i}^2\right) + \sum_{i}^{} \sum_{j}^{} \frac{1}{2} \frac{q_{i}\,q_{j}}{c^2}\,\frac{\left(\dot{x_i}\dot{x_j} + \dot{y_i}\dot{y_j}+\dot{z_i}\dot{z_j}\right)}{r} - V(r)$

# %% [markdown]
# $L = \sum_{i}^{} \frac{1}{2} m_i \left(\dot{x_i}^2+\dot{y_i}^2+\dot{z_i}^2\right) + \sum_{i}^{} \sum_{j}^{} \frac{1}{2} \frac{q_{i}\,q_{j}}{c^2}\,\frac{\left(\dot{x_i}\dot{x_j} + \dot{y_i}\dot{y_j}+\dot{z_i}\dot{z_j}\right)}{\sqrt{\left(x_i-x_j\right)^2+\left(y_i-y_j\right)^2+\left(z_i-z_j\right)^2}} - V\left(\sqrt{\left(x_i-x_j\right)^2+\left(y_i-y_j\right)^2+\left(z_i-z_j\right)^2}\right)$

# %% [markdown]
# Далее в данной работе введём коэффициент $С = \frac{1}{2} \frac{q_{i}\,q_{j}}{c^2}$. Если сфера имеет распределение заряда отличающееся от равномерного коэффициент $С$ получит иное выражение. В данной работе будем рассматривать этот коэффициент как изменяемый параметр.

# %%
from IPython.display import display, Math, Latex

def disp(ex):
    display(Math(latex(ex)))

def displ(tex):
    display(Math(tex))

# %%
# Объявление переменных и функций

m_1,m_2 = var("m_1,m_2")
t = var("t")
C = var("C")

V_x_1 = var("v_x_1")
v_x_1 = function("v_x_1")(t)

V_x_2 = var("v_x_2")
v_x_2 = function("v_x_2")(t)

V_y_1 = var("v_y_1")
v_y_1 = function("v_y_1")(t)

V_y_2 = var("v_y_2")
v_y_2 = function("v_y_2")(t)

V_z_1 = var("v_z_1")
v_z_1 = function("v_z_1")(t)

V_z_2 = var("v_z_2")
v_z_2 = function("v_z_2")(t)

X_1 = var("x_1")
x_1 = function("x_1")(t)

X_2 = var("x_2")
x_2 = function("x_2")(t)

Y_1 = var("y_1")
y_1 = function("y_1")(t)

Y_2 = var("y_2")
y_2 = function("y_2")(t)

Z_1 = var("z_1")
z_1 = function("z_1")(t)

Z_2 = var("z_2")
z_2 = function("z_2")(t)

r = var("r")
V = function("V")(r)

P = var("p")
p = function("p")(t)

# %%
# Lennard Jones
V = 1/r^12-1/r^6

# %%
# Кинетическая энергия

T = (1/2) * m_1 * ((x_1.diff(t))^2 + (y_1.diff(t))^2 + (z_1.diff(t))^2) \
  + (1/2) * m_2 * ((x_2.diff(t))^2 + (y_2.diff(t))^2 + (z_2.diff(t))^2) \
  + C * (x_1.diff(t)*x_2.diff(t) + y_1.diff(t)*y_2.diff(t) + z_1.diff(t)*z_2.diff(t)) \
  / sqrt((x_1 - x_2)^2 + (y_1 - y_2)^2 + (z_1 - z_2)^2)
disp(T)
# Out:
# $\displaystyle \frac{1}{2} \, {\left(\frac{\partial}{\partial t}x_{1}\left(t\right)^{2} + \frac{\partial}{\partial t}y_{1}\left(t\right)^{2} + \frac{\partial}{\partial t}z_{1}\left(t\right)^{2}\right)} m_{1} + \frac{1}{2} \, {\left(\frac{\partial}{\partial t}x_{2}\left(t\right)^{2} + \frac{\partial}{\partial t}y_{2}\left(t\right)^{2} + \frac{\partial}{\partial t}z_{2}\left(t\right)^{2}\right)} m_{2} + \frac{{\left(\frac{\partial}{\partial t}x_{1}\left(t\right) \frac{\partial}{\partial t}x_{2}\left(t\right) + \frac{\partial}{\partial t}y_{1}\left(t\right) \frac{\partial}{\partial t}y_{2}\left(t\right) + \frac{\partial}{\partial t}z_{1}\left(t\right) \frac{\partial}{\partial t}z_{2}\left(t\right)\right)} C}{\sqrt{{\left(x_{1}\left(t\right) - x_{2}\left(t\right)\right)}^{2} + {\left(y_{1}\left(t\right) - y_{2}\left(t\right)\right)}^{2} + {\left(z_{1}\left(t\right) - z_{2}\left(t\right)\right)}^{2}}}$

# %%
U = V(r = sqrt((x_1 - x_2)^2 + (y_1 - y_2)^2 + (z_1 - z_2)^2))
disp(U)
# Out:
# $\displaystyle -\frac{1}{{\left({\left(x_{1}\left(t\right) - x_{2}\left(t\right)\right)}^{2} + {\left(y_{1}\left(t\right) - y_{2}\left(t\right)\right)}^{2} + {\left(z_{1}\left(t\right) - z_{2}\left(t\right)\right)}^{2}\right)}^{3}} + \frac{1}{{\left({\left(x_{1}\left(t\right) - x_{2}\left(t\right)\right)}^{2} + {\left(y_{1}\left(t\right) - y_{2}\left(t\right)\right)}^{2} + {\left(z_{1}\left(t\right) - z_{2}\left(t\right)\right)}^{2}\right)}^{6}}$

# %%
L = T - U
disp(L)
# Out:
# $\displaystyle \frac{1}{2} \, {\left(\frac{\partial}{\partial t}x_{1}\left(t\right)^{2} + \frac{\partial}{\partial t}y_{1}\left(t\right)^{2} + \frac{\partial}{\partial t}z_{1}\left(t\right)^{2}\right)} m_{1} + \frac{1}{2} \, {\left(\frac{\partial}{\partial t}x_{2}\left(t\right)^{2} + \frac{\partial}{\partial t}y_{2}\left(t\right)^{2} + \frac{\partial}{\partial t}z_{2}\left(t\right)^{2}\right)} m_{2} + \frac{{\left(\frac{\partial}{\partial t}x_{1}\left(t\right) \frac{\partial}{\partial t}x_{2}\left(t\right) + \frac{\partial}{\partial t}y_{1}\left(t\right) \frac{\partial}{\partial t}y_{2}\left(t\right) + \frac{\partial}{\partial t}z_{1}\left(t\right) \frac{\partial}{\partial t}z_{2}\left(t\right)\right)} C}{\sqrt{{\left(x_{1}\left(t\right) - x_{2}\left(t\right)\right)}^{2} + {\left(y_{1}\left(t\right) - y_{2}\left(t\right)\right)}^{2} + {\left(z_{1}\left(t\right) - z_{2}\left(t\right)\right)}^{2}}} + \frac{1}{{\left({\left(x_{1}\left(t\right) - x_{2}\left(t\right)\right)}^{2} + {\left(y_{1}\left(t\right) - y_{2}\left(t\right)\right)}^{2} + {\left(z_{1}\left(t\right) - z_{2}\left(t\right)\right)}^{2}\right)}^{3}} - \frac{1}{{\left({\left(x_{1}\left(t\right) - x_{2}\left(t\right)\right)}^{2} + {\left(y_{1}\left(t\right) - y_{2}\left(t\right)\right)}^{2} + {\left(z_{1}\left(t\right) - z_{2}\left(t\right)\right)}^{2}\right)}^{6}}$

# %%
# уравнения замены производных обобщенных координат на v

xdot_to_v      = [x_1.diff(t) == V_x_1,
                  y_1.diff(t) == V_y_1,
                  z_1.diff(t) == V_z_1,
                  x_2.diff(t) == V_x_2,
                  y_2.diff(t) == V_y_2,
                  z_2.diff(t) == V_z_2,
                 ]
disp(xdot_to_v)

xdot_to_v_func = [x_1.diff(t) == v_x_1,
                  y_1.diff(t) == v_y_1,
                  z_1.diff(t) == v_z_1,
                  x_2.diff(t) == v_x_2,
                  y_2.diff(t) == v_y_2,
                  z_2.diff(t) == v_z_2,
                 ]
disp(xdot_to_v_func)
# Out:
# $\displaystyle \left[\frac{\partial}{\partial t}x_{1}\left(t\right) = v_{x_{1}}, \frac{\partial}{\partial t}y_{1}\left(t\right) = v_{y_{1}}, \frac{\partial}{\partial t}z_{1}\left(t\right) = v_{z_{1}}, \frac{\partial}{\partial t}x_{2}\left(t\right) = v_{x_{2}}, \frac{\partial}{\partial t}y_{2}\left(t\right) = v_{y_{2}}, \frac{\partial}{\partial t}z_{2}\left(t\right) = v_{z_{2}}\right]$
# $\displaystyle \left[\frac{\partial}{\partial t}x_{1}\left(t\right) = v_{x_{1}}\left(t\right), \frac{\partial}{\partial t}y_{1}\left(t\right) = v_{y_{1}}\left(t\right), \frac{\partial}{\partial t}z_{1}\left(t\right) = v_{z_{1}}\left(t\right), \frac{\partial}{\partial t}x_{2}\left(t\right) = v_{x_{2}}\left(t\right), \frac{\partial}{\partial t}y_{2}\left(t\right) = v_{y_{2}}\left(t\right), \frac{\partial}{\partial t}z_{2}\left(t\right) = v_{z_{2}}\left(t\right)\right]$

# %%
# уравнения замены производных обобщенных координат на v

v_to_xdot      = [V_x_1 == x_1.diff(t),
                  V_y_1 == y_1.diff(t),
                  V_z_1 == z_1.diff(t),
                  V_x_2 == x_2.diff(t),
                  V_y_2 == y_2.diff(t),
                  V_z_2 == z_2.diff(t),
                 ]
disp(v_to_xdot)
# Out:
# $\displaystyle \left[v_{x_{1}} = \frac{\partial}{\partial t}x_{1}\left(t\right), v_{y_{1}} = \frac{\partial}{\partial t}y_{1}\left(t\right), v_{z_{1}} = \frac{\partial}{\partial t}z_{1}\left(t\right), v_{x_{2}} = \frac{\partial}{\partial t}x_{2}\left(t\right), v_{y_{2}} = \frac{\partial}{\partial t}y_{2}\left(t\right), v_{z_{2}} = \frac{\partial}{\partial t}z_{2}\left(t\right)\right]$

# %%
X_to_x = [X_1 == x_1,
          Y_1 == y_1,
          Z_1 == z_1,
          X_2 == x_2,
          Y_2 == y_2,
          Z_2 == z_2,
         ]
disp(X_to_x)
# Out:
# $\displaystyle \left[x_{1} = x_{1}\left(t\right), y_{1} = y_{1}\left(t\right), z_{1} = z_{1}\left(t\right), x_{2} = x_{2}\left(t\right), y_{2} = y_{2}\left(t\right), z_{2} = z_{2}\left(t\right)\right]$

# %%
x_to_X = [x_1 == X_1,
          y_1 == Y_1,
          z_1 == Z_1,
          x_2 == X_2,
          y_2 == Y_2,
          z_2 == Z_2,
         ]
disp(x_to_X)
# Out:
# $\displaystyle \left[x_{1}\left(t\right) = x_{1}, y_{1}\left(t\right) = y_{1}, z_{1}\left(t\right) = z_{1}, x_{2}\left(t\right) = x_{2}, y_{2}\left(t\right) = y_{2}, z_{2}\left(t\right) = z_{2}\right]$

# %% [markdown]
# Найдем обобщенные импульсы
#
# $P = \frac{\partial L}{\partial \dot{x}} = \frac{\partial L}{\partial {v}}$

# %%
L_ = L.subs(xdot_to_v)
disp(L_)
# Out:
# $\displaystyle \frac{1}{2} \, {\left(v_{x_{1}}^{2} + v_{y_{1}}^{2} + v_{z_{1}}^{2}\right)} m_{1} + \frac{1}{2} \, {\left(v_{x_{2}}^{2} + v_{y_{2}}^{2} + v_{z_{2}}^{2}\right)} m_{2} + \frac{{\left(v_{x_{1}} v_{x_{2}} + v_{y_{1}} v_{y_{2}} + v_{z_{1}} v_{z_{2}}\right)} C}{\sqrt{{\left(x_{1}\left(t\right) - x_{2}\left(t\right)\right)}^{2} + {\left(y_{1}\left(t\right) - y_{2}\left(t\right)\right)}^{2} + {\left(z_{1}\left(t\right) - z_{2}\left(t\right)\right)}^{2}}} + \frac{1}{{\left({\left(x_{1}\left(t\right) - x_{2}\left(t\right)\right)}^{2} + {\left(y_{1}\left(t\right) - y_{2}\left(t\right)\right)}^{2} + {\left(z_{1}\left(t\right) - z_{2}\left(t\right)\right)}^{2}\right)}^{3}} - \frac{1}{{\left({\left(x_{1}\left(t\right) - x_{2}\left(t\right)\right)}^{2} + {\left(y_{1}\left(t\right) - y_{2}\left(t\right)\right)}^{2} + {\left(z_{1}\left(t\right) - z_{2}\left(t\right)\right)}^{2}\right)}^{6}}$

# %%
Px1 = L_.diff(V_x_1).subs(v_to_xdot)
Px2 = L_.diff(V_x_2).subs(v_to_xdot)

displ("Px_1=" + latex(Px1))
displ("Px_2=" + latex(Px2))
print("")

Py1 = L_.diff(V_y_1).subs(v_to_xdot)
Py2 = L_.diff(V_y_2).subs(v_to_xdot)

displ("Py_1="+latex(Py1))
displ("Py_2="+latex(Py2))
print("")

Pz1 = L_.diff(V_z_1).subs(v_to_xdot)
Pz2 = L_.diff(V_z_2).subs(v_to_xdot)

displ("Pz_1="+latex(Pz1))
displ("Pz_2="+latex(Pz2))
# Out:
# $\displaystyle Px_1= m_{1} \frac{\partial}{\partial t}x_{1}\left(t\right) + \frac{C \frac{\partial}{\partial t}x_{2}\left(t\right)}{\sqrt{{\left(x_{1}\left(t\right) - x_{2}\left(t\right)\right)}^{2} + {\left(y_{1}\left(t\right) - y_{2}\left(t\right)\right)}^{2} + {\left(z_{1}\left(t\right) - z_{2}\left(t\right)\right)}^{2}}}$
# $\displaystyle Px_2= m_{2} \frac{\partial}{\partial t}x_{2}\left(t\right) + \frac{C \frac{\partial}{\partial t}x_{1}\left(t\right)}{\sqrt{{\left(x_{1}\left(t\right) - x_{2}\left(t\right)\right)}^{2} + {\left(y_{1}\left(t\right) - y_{2}\left(t\right)\right)}^{2} + {\left(z_{1}\left(t\right) - z_{2}\left(t\right)\right)}^{2}}}$
# $\displaystyle Py_1= m_{1} \frac{\partial}{\partial t}y_{1}\left(t\right) + \frac{C \frac{\partial}{\partial t}y_{2}\left(t\right)}{\sqrt{{\left(x_{1}\left(t\right) - x_{2}\left(t\right)\right)}^{2} + {\left(y_{1}\left(t\right) - y_{2}\left(t\right)\right)}^{2} + {\left(z_{1}\left(t\right) - z_{2}\left(t\right)\right)}^{2}}}$
# $\displaystyle Py_2= m_{2} \frac{\partial}{\partial t}y_{2}\left(t\right) + \frac{C \frac{\partial}{\partial t}y_{1}\left(t\right)}{\sqrt{{\left(x_{1}\left(t\right) - x_{2}\left(t\right)\right)}^{2} + {\left(y_{1}\left(t\right) - y_{2}\left(t\right)\right)}^{2} + {\left(z_{1}\left(t\right) - z_{2}\left(t\right)\right)}^{2}}}$
# $\displaystyle Pz_1= m_{1} \frac{\partial}{\partial t}z_{1}\left(t\right) + \frac{C \frac{\partial}{\partial t}z_{2}\left(t\right)}{\sqrt{{\left(x_{1}\left(t\right) - x_{2}\left(t\right)\right)}^{2} + {\left(y_{1}\left(t\right) - y_{2}\left(t\right)\right)}^{2} + {\left(z_{1}\left(t\right) - z_{2}\left(t\right)\right)}^{2}}}$
# $\displaystyle Pz_2= m_{2} \frac{\partial}{\partial t}z_{2}\left(t\right) + \frac{C \frac{\partial}{\partial t}z_{1}\left(t\right)}{\sqrt{{\left(x_{1}\left(t\right) - x_{2}\left(t\right)\right)}^{2} + {\left(y_{1}\left(t\right) - y_{2}\left(t\right)\right)}^{2} + {\left(z_{1}\left(t\right) - z_{2}\left(t\right)\right)}^{2}}}$

# %% [markdown]
# Найдем обобщенные силы
#
# $\frac{\partial L}{\partial {x}} = F$

# %%
Fx1 = L.subs(x_to_X).diff(X_1).subs(X_to_x)
Fx2 = L.subs(x_to_X).diff(X_2).subs(X_to_x)

Fy1 = L.subs(x_to_X).diff(Y_1).subs(X_to_x)
Fy2 = L.subs(x_to_X).diff(Y_2).subs(X_to_x)

Fz1 = L.subs(x_to_X).diff(Z_1).subs(X_to_x)
Fz2 = L.subs(x_to_X).diff(Z_2).subs(X_to_x)

displ("Fx_1=" + latex(Fx1))
displ("Fx_2=" + latex(Fx2))
print("")

displ("Fy_1=" + latex(Fy1))
displ("Fy_2=" + latex(Fx2))
print("")

displ("Fz_1=" + latex(Fz1))
displ("Fx_2=" + latex(Fz2))
# Out:
# $\displaystyle Fx_1= -\frac{{\left(\frac{\partial}{\partial t}x_{1}\left(t\right) \frac{\partial}{\partial t}x_{2}\left(t\right) + \frac{\partial}{\partial t}y_{1}\left(t\right) \frac{\partial}{\partial t}y_{2}\left(t\right) + \frac{\partial}{\partial t}z_{1}\left(t\right) \frac{\partial}{\partial t}z_{2}\left(t\right)\right)} C {\left(x_{1}\left(t\right) - x_{2}\left(t\right)\right)}}{{\left({\left(x_{1}\left(t\right) - x_{2}\left(t\right)\right)}^{2} + {\left(y_{1}\left(t\right) - y_{2}\left(t\right)\right)}^{2} + {\left(z_{1}\left(t\right) - z_{2}\left(t\right)\right)}^{2}\right)}^{\frac{3}{2}}} - \frac{6 \, {\left(x_{1}\left(t\right) - x_{2}\left(t\right)\right)}}{{\left({\left(x_{1}\left(t\right) - x_{2}\left(t\right)\right)}^{2} + {\left(y_{1}\left(t\right) - y_{2}\left(t\right)\right)}^{2} + {\left(z_{1}\left(t\right) - z_{2}\left(t\right)\right)}^{2}\right)}^{4}} + \frac{12 \, {\left(x_{1}\left(t\right) - x_{2}\left(t\right)\right)}}{{\left({\left(x_{1}\left(t\right) - x_{2}\left(t\right)\right)}^{2} + {\left(y_{1}\left(t\right) - y_{2}\left(t\right)\right)}^{2} + {\left(z_{1}\left(t\right) - z_{2}\left(t\right)\right)}^{2}\right)}^{7}}$
# $\displaystyle Fx_2= \frac{{\left(\frac{\partial}{\partial t}x_{1}\left(t\right) \frac{\partial}{\partial t}x_{2}\left(t\right) + \frac{\partial}{\partial t}y_{1}\left(t\right) \frac{\partial}{\partial t}y_{2}\left(t\right) + \frac{\partial}{\partial t}z_{1}\left(t\right) \frac{\partial}{\partial t}z_{2}\left(t\right)\right)} C {\left(x_{1}\left(t\right) - x_{2}\left(t\right)\right)}}{{\left({\left(x_{1}\left(t\right) - x_{2}\left(t\right)\right)}^{2} + {\left(y_{1}\left(t\right) - y_{2}\left(t\right)\right)}^{2} + {\left(z_{1}\left(t\right) - z_{2}\left(t\right)\right)}^{2}\right)}^{\frac{3}{2}}} + \frac{6 \, {\left(x_{1}\left(t\right) - x_{2}\left(t\right)\right)}}{{\left({\left(x_{1}\left(t\right) - x_{2}\left(t\right)\right)}^{2} + {\left(y_{1}\left(t\right) - y_{2}\left(t\right)\right)}^{2} + {\left(z_{1}\left(t\right) - z_{2}\left(t\right)\right)}^{2}\right)}^{4}} - \frac{12 \, {\left(x_{1}\left(t\right) - x_{2}\left(t\right)\right)}}{{\left({\left(x_{1}\left(t\right) - x_{2}\left(t\right)\right)}^{2} + {\left(y_{1}\left(t\right) - y_{2}\left(t\right)\right)}^{2} + {\left(z_{1}\left(t\right) - z_{2}\left(t\right)\right)}^{2}\right)}^{7}}$
# $\displaystyle Fy_1= -\frac{{\left(\frac{\partial}{\partial t}x_{1}\left(t\right) \frac{\partial}{\partial t}x_{2}\left(t\right) + \frac{\partial}{\partial t}y_{1}\left(t\right) \frac{\partial}{\partial t}y_{2}\left(t\right) + \frac{\partial}{\partial t}z_{1}\left(t\right) \frac{\partial}{\partial t}z_{2}\left(t\right)\right)} C {\left(y_{1}\left(t\right) - y_{2}\left(t\right)\right)}}{{\left({\left(x_{1}\left(t\right) - x_{2}\left(t\right)\right)}^{2} + {\left(y_{1}\left(t\right) - y_{2}\left(t\right)\right)}^{2} + {\left(z_{1}\left(t\right) - z_{2}\left(t\right)\right)}^{2}\right)}^{\frac{3}{2}}} - \frac{6 \, {\left(y_{1}\left(t\right) - y_{2}\left(t\right)\right)}}{{\left({\left(x_{1}\left(t\right) - x_{2}\left(t\right)\right)}^{2} + {\left(y_{1}\left(t\right) - y_{2}\left(t\right)\right)}^{2} + {\left(z_{1}\left(t\right) - z_{2}\left(t\right)\right)}^{2}\right)}^{4}} + \frac{12 \, {\left(y_{1}\left(t\right) - y_{2}\left(t\right)\right)}}{{\left({\left(x_{1}\left(t\right) - x_{2}\left(t\right)\right)}^{2} + {\left(y_{1}\left(t\right) - y_{2}\left(t\right)\right)}^{2} + {\left(z_{1}\left(t\right) - z_{2}\left(t\right)\right)}^{2}\right)}^{7}}$
# $\displaystyle Fy_2= \frac{{\left(\frac{\partial}{\partial t}x_{1}\left(t\right) \frac{\partial}{\partial t}x_{2}\left(t\right) + \frac{\partial}{\partial t}y_{1}\left(t\right) \frac{\partial}{\partial t}y_{2}\left(t\right) + \frac{\partial}{\partial t}z_{1}\left(t\right) \frac{\partial}{\partial t}z_{2}\left(t\right)\right)} C {\left(x_{1}\left(t\right) - x_{2}\left(t\right)\right)}}{{\left({\left(x_{1}\left(t\right) - x_{2}\left(t\right)\right)}^{2} + {\left(y_{1}\left(t\right) - y_{2}\left(t\right)\right)}^{2} + {\left(z_{1}\left(t\right) - z_{2}\left(t\right)\right)}^{2}\right)}^{\frac{3}{2}}} + \frac{6 \, {\left(x_{1}\left(t\right) - x_{2}\left(t\right)\right)}}{{\left({\left(x_{1}\left(t\right) - x_{2}\left(t\right)\right)}^{2} + {\left(y_{1}\left(t\right) - y_{2}\left(t\right)\right)}^{2} + {\left(z_{1}\left(t\right) - z_{2}\left(t\right)\right)}^{2}\right)}^{4}} - \frac{12 \, {\left(x_{1}\left(t\right) - x_{2}\left(t\right)\right)}}{{\left({\left(x_{1}\left(t\right) - x_{2}\left(t\right)\right)}^{2} + {\left(y_{1}\left(t\right) - y_{2}\left(t\right)\right)}^{2} + {\left(z_{1}\left(t\right) - z_{2}\left(t\right)\right)}^{2}\right)}^{7}}$
# $\displaystyle Fz_1= -\frac{{\left(\frac{\partial}{\partial t}x_{1}\left(t\right) \frac{\partial}{\partial t}x_{2}\left(t\right) + \frac{\partial}{\partial t}y_{1}\left(t\right) \frac{\partial}{\partial t}y_{2}\left(t\right) + \frac{\partial}{\partial t}z_{1}\left(t\right) \frac{\partial}{\partial t}z_{2}\left(t\right)\right)} C {\left(z_{1}\left(t\right) - z_{2}\left(t\right)\right)}}{{\left({\left(x_{1}\left(t\right) - x_{2}\left(t\right)\right)}^{2} + {\left(y_{1}\left(t\right) - y_{2}\left(t\right)\right)}^{2} + {\left(z_{1}\left(t\right) - z_{2}\left(t\right)\right)}^{2}\right)}^{\frac{3}{2}}} - \frac{6 \, {\left(z_{1}\left(t\right) - z_{2}\left(t\right)\right)}}{{\left({\left(x_{1}\left(t\right) - x_{2}\left(t\right)\right)}^{2} + {\left(y_{1}\left(t\right) - y_{2}\left(t\right)\right)}^{2} + {\left(z_{1}\left(t\right) - z_{2}\left(t\right)\right)}^{2}\right)}^{4}} + \frac{12 \, {\left(z_{1}\left(t\right) - z_{2}\left(t\right)\right)}}{{\left({\left(x_{1}\left(t\right) - x_{2}\left(t\right)\right)}^{2} + {\left(y_{1}\left(t\right) - y_{2}\left(t\right)\right)}^{2} + {\left(z_{1}\left(t\right) - z_{2}\left(t\right)\right)}^{2}\right)}^{7}}$
# $\displaystyle Fx_2= \frac{{\left(\frac{\partial}{\partial t}x_{1}\left(t\right) \frac{\partial}{\partial t}x_{2}\left(t\right) + \frac{\partial}{\partial t}y_{1}\left(t\right) \frac{\partial}{\partial t}y_{2}\left(t\right) + \frac{\partial}{\partial t}z_{1}\left(t\right) \frac{\partial}{\partial t}z_{2}\left(t\right)\right)} C {\left(z_{1}\left(t\right) - z_{2}\left(t\right)\right)}}{{\left({\left(x_{1}\left(t\right) - x_{2}\left(t\right)\right)}^{2} + {\left(y_{1}\left(t\right) - y_{2}\left(t\right)\right)}^{2} + {\left(z_{1}\left(t\right) - z_{2}\left(t\right)\right)}^{2}\right)}^{\frac{3}{2}}} + \frac{6 \, {\left(z_{1}\left(t\right) - z_{2}\left(t\right)\right)}}{{\left({\left(x_{1}\left(t\right) - x_{2}\left(t\right)\right)}^{2} + {\left(y_{1}\left(t\right) - y_{2}\left(t\right)\right)}^{2} + {\left(z_{1}\left(t\right) - z_{2}\left(t\right)\right)}^{2}\right)}^{4}} - \frac{12 \, {\left(z_{1}\left(t\right) - z_{2}\left(t\right)\right)}}{{\left({\left(x_{1}\left(t\right) - x_{2}\left(t\right)\right)}^{2} + {\left(y_{1}\left(t\right) - y_{2}\left(t\right)\right)}^{2} + {\left(z_{1}\left(t\right) - z_{2}\left(t\right)\right)}^{2}\right)}^{7}}$

# %% [markdown]
# Запишем уравнения Эйлера-Лагранжа
#
# $\frac{d}{dt}\frac{\partial L}{\partial \dot{x}} - \frac{\partial L}{\partial {x}} = 0$

# %%
dex1 = Px1.diff(t) - Fx1 == 0
deX1 = dex1.subs(xdot_to_v).subs(x_to_X)
disp(deX1)
# Out:
# $\displaystyle m_{1} \frac{\partial^{2}}{(\partial t)^{2}}x_{1}\left(t\right) - \frac{{\left({\left(v_{x_{1}} - v_{x_{2}}\right)} {\left(x_{1} - x_{2}\right)} + {\left(v_{y_{1}} - v_{y_{2}}\right)} {\left(y_{1} - y_{2}\right)} + {\left(v_{z_{1}} - v_{z_{2}}\right)} {\left(z_{1} - z_{2}\right)}\right)} C v_{x_{2}}}{{\left({\left(x_{1} - x_{2}\right)}^{2} + {\left(y_{1} - y_{2}\right)}^{2} + {\left(z_{1} - z_{2}\right)}^{2}\right)}^{\frac{3}{2}}} + \frac{{\left(v_{x_{1}} v_{x_{2}} + v_{y_{1}} v_{y_{2}} + v_{z_{1}} v_{z_{2}}\right)} C {\left(x_{1} - x_{2}\right)}}{{\left({\left(x_{1} - x_{2}\right)}^{2} + {\left(y_{1} - y_{2}\right)}^{2} + {\left(z_{1} - z_{2}\right)}^{2}\right)}^{\frac{3}{2}}} + \frac{C \frac{\partial^{2}}{(\partial t)^{2}}x_{2}\left(t\right)}{\sqrt{{\left(x_{1} - x_{2}\right)}^{2} + {\left(y_{1} - y_{2}\right)}^{2} + {\left(z_{1} - z_{2}\right)}^{2}}} + \frac{6 \, {\left(x_{1} - x_{2}\right)}}{{\left({\left(x_{1} - x_{2}\right)}^{2} + {\left(y_{1} - y_{2}\right)}^{2} + {\left(z_{1} - z_{2}\right)}^{2}\right)}^{4}} - \frac{12 \, {\left(x_{1} - x_{2}\right)}}{{\left({\left(x_{1} - x_{2}\right)}^{2} + {\left(y_{1} - y_{2}\right)}^{2} + {\left(z_{1} - z_{2}\right)}^{2}\right)}^{7}} = 0$

# %%
dex2 = Px2.diff(t) - Fx2 == 0
deX2 = dex2.subs(xdot_to_v).subs(x_to_X)
disp(deX2)
# Out:
# $\displaystyle m_{2} \frac{\partial^{2}}{(\partial t)^{2}}x_{2}\left(t\right) - \frac{{\left({\left(v_{x_{1}} - v_{x_{2}}\right)} {\left(x_{1} - x_{2}\right)} + {\left(v_{y_{1}} - v_{y_{2}}\right)} {\left(y_{1} - y_{2}\right)} + {\left(v_{z_{1}} - v_{z_{2}}\right)} {\left(z_{1} - z_{2}\right)}\right)} C v_{x_{1}}}{{\left({\left(x_{1} - x_{2}\right)}^{2} + {\left(y_{1} - y_{2}\right)}^{2} + {\left(z_{1} - z_{2}\right)}^{2}\right)}^{\frac{3}{2}}} - \frac{{\left(v_{x_{1}} v_{x_{2}} + v_{y_{1}} v_{y_{2}} + v_{z_{1}} v_{z_{2}}\right)} C {\left(x_{1} - x_{2}\right)}}{{\left({\left(x_{1} - x_{2}\right)}^{2} + {\left(y_{1} - y_{2}\right)}^{2} + {\left(z_{1} - z_{2}\right)}^{2}\right)}^{\frac{3}{2}}} + \frac{C \frac{\partial^{2}}{(\partial t)^{2}}x_{1}\left(t\right)}{\sqrt{{\left(x_{1} - x_{2}\right)}^{2} + {\left(y_{1} - y_{2}\right)}^{2} + {\left(z_{1} - z_{2}\right)}^{2}}} - \frac{6 \, {\left(x_{1} - x_{2}\right)}}{{\left({\left(x_{1} - x_{2}\right)}^{2} + {\left(y_{1} - y_{2}\right)}^{2} + {\left(z_{1} - z_{2}\right)}^{2}\right)}^{4}} + \frac{12 \, {\left(x_{1} - x_{2}\right)}}{{\left({\left(x_{1} - x_{2}\right)}^{2} + {\left(y_{1} - y_{2}\right)}^{2} + {\left(z_{1} - z_{2}\right)}^{2}\right)}^{7}} = 0$

# %%
disp((deX2-deX1))
# Out:
# $\displaystyle -m_{1} \frac{\partial^{2}}{(\partial t)^{2}}x_{1}\left(t\right) + m_{2} \frac{\partial^{2}}{(\partial t)^{2}}x_{2}\left(t\right) - \frac{{\left({\left(v_{x_{1}} - v_{x_{2}}\right)} {\left(x_{1} - x_{2}\right)} + {\left(v_{y_{1}} - v_{y_{2}}\right)} {\left(y_{1} - y_{2}\right)} + {\left(v_{z_{1}} - v_{z_{2}}\right)} {\left(z_{1} - z_{2}\right)}\right)} C v_{x_{1}}}{{\left({\left(x_{1} - x_{2}\right)}^{2} + {\left(y_{1} - y_{2}\right)}^{2} + {\left(z_{1} - z_{2}\right)}^{2}\right)}^{\frac{3}{2}}} + \frac{{\left({\left(v_{x_{1}} - v_{x_{2}}\right)} {\left(x_{1} - x_{2}\right)} + {\left(v_{y_{1}} - v_{y_{2}}\right)} {\left(y_{1} - y_{2}\right)} + {\left(v_{z_{1}} - v_{z_{2}}\right)} {\left(z_{1} - z_{2}\right)}\right)} C v_{x_{2}}}{{\left({\left(x_{1} - x_{2}\right)}^{2} + {\left(y_{1} - y_{2}\right)}^{2} + {\left(z_{1} - z_{2}\right)}^{2}\right)}^{\frac{3}{2}}} - \frac{2 \, {\left(v_{x_{1}} v_{x_{2}} + v_{y_{1}} v_{y_{2}} + v_{z_{1}} v_{z_{2}}\right)} C {\left(x_{1} - x_{2}\right)}}{{\left({\left(x_{1} - x_{2}\right)}^{2} + {\left(y_{1} - y_{2}\right)}^{2} + {\left(z_{1} - z_{2}\right)}^{2}\right)}^{\frac{3}{2}}} + \frac{C \frac{\partial^{2}}{(\partial t)^{2}}x_{1}\left(t\right)}{\sqrt{{\left(x_{1} - x_{2}\right)}^{2} + {\left(y_{1} - y_{2}\right)}^{2} + {\left(z_{1} - z_{2}\right)}^{2}}} - \frac{C \frac{\partial^{2}}{(\partial t)^{2}}x_{2}\left(t\right)}{\sqrt{{\left(x_{1} - x_{2}\right)}^{2} + {\left(y_{1} - y_{2}\right)}^{2} + {\left(z_{1} - z_{2}\right)}^{2}}} - \frac{12 \, {\left(x_{1} - x_{2}\right)}}{{\left({\left(x_{1} - x_{2}\right)}^{2} + {\left(y_{1} - y_{2}\right)}^{2} + {\left(z_{1} - z_{2}\right)}^{2}\right)}^{4}} + \frac{24 \, {\left(x_{1} - x_{2}\right)}}{{\left({\left(x_{1} - x_{2}\right)}^{2} + {\left(y_{1} - y_{2}\right)}^{2} + {\left(z_{1} - z_{2}\right)}^{2}\right)}^{7}} = 0$

# %% [markdown]
# Выразим энергию через Лагранжиан
#
# $E = \Sigma_{i}^{} \frac {\partial L}{\partial \dot{q}_i} \frac {q_i}{dt} - L$

# %%
E = Px1 * x_1.diff(t) + Px2 * x_2.diff(t) \
  + Py1 * y_1.diff(t) + Py2 * y_2.diff(t) \
  + Pz1 * z_1.diff(t) + Pz2 * z_2.diff(t) \
  - L
E = E.expand()
#disp(E)

# %%
Ev = E.subs(xdot_to_v)
#disp(Ev)

# %% [markdown]
# # Интегрирование уравнений Гамильтона

# %%
# Объявление переменных - обобщенные импульсы

p_x_1, p_x_2 = var("p_x_1, p_x_2")
p_y_1, p_y_2 = var("p_y_1, p_y_2")
p_z_1, p_z_2 = var("p_z_1, p_z_2")

# %%
V = [V_x_1, V_x_2, V_y_1, V_y_2, V_z_1, V_z_2]
X = [  X_1,   X_2,   Y_1,   Y_2,   Z_1,   Z_2]
P = [p_x_1, p_x_2, p_y_1, p_y_2, p_z_1, p_z_2]

# %%
# Записываем уравнения выражающие обобщенные импульсы
# через производные Лагранжиана по скорости изменения обобщенной координаты (по v)

eq_p_v = [p_x_1 == L_.diff(V_x_1),
          p_x_2 == L_.diff(V_x_2),
          p_y_1 == L_.diff(V_y_1),
          p_y_2 == L_.diff(V_y_2),
          p_z_1 == L_.diff(V_z_1),
          p_z_2 == L_.diff(V_z_2),
         ]
for eq_p in eq_p_v:
    disp(eq_p)
# Out:
# $\displaystyle p_{x_{1}} = m_{1} v_{x_{1}} + \frac{C v_{x_{2}}}{\sqrt{{\left(x_{1}\left(t\right) - x_{2}\left(t\right)\right)}^{2} + {\left(y_{1}\left(t\right) - y_{2}\left(t\right)\right)}^{2} + {\left(z_{1}\left(t\right) - z_{2}\left(t\right)\right)}^{2}}}$
# $\displaystyle p_{x_{2}} = m_{2} v_{x_{2}} + \frac{C v_{x_{1}}}{\sqrt{{\left(x_{1}\left(t\right) - x_{2}\left(t\right)\right)}^{2} + {\left(y_{1}\left(t\right) - y_{2}\left(t\right)\right)}^{2} + {\left(z_{1}\left(t\right) - z_{2}\left(t\right)\right)}^{2}}}$
# $\displaystyle p_{y_{1}} = m_{1} v_{y_{1}} + \frac{C v_{y_{2}}}{\sqrt{{\left(x_{1}\left(t\right) - x_{2}\left(t\right)\right)}^{2} + {\left(y_{1}\left(t\right) - y_{2}\left(t\right)\right)}^{2} + {\left(z_{1}\left(t\right) - z_{2}\left(t\right)\right)}^{2}}}$
# $\displaystyle p_{y_{2}} = m_{2} v_{y_{2}} + \frac{C v_{y_{1}}}{\sqrt{{\left(x_{1}\left(t\right) - x_{2}\left(t\right)\right)}^{2} + {\left(y_{1}\left(t\right) - y_{2}\left(t\right)\right)}^{2} + {\left(z_{1}\left(t\right) - z_{2}\left(t\right)\right)}^{2}}}$
# $\displaystyle p_{z_{1}} = m_{1} v_{z_{1}} + \frac{C v_{z_{2}}}{\sqrt{{\left(x_{1}\left(t\right) - x_{2}\left(t\right)\right)}^{2} + {\left(y_{1}\left(t\right) - y_{2}\left(t\right)\right)}^{2} + {\left(z_{1}\left(t\right) - z_{2}\left(t\right)\right)}^{2}}}$
# $\displaystyle p_{z_{2}} = m_{2} v_{z_{2}} + \frac{C v_{z_{1}}}{\sqrt{{\left(x_{1}\left(t\right) - x_{2}\left(t\right)\right)}^{2} + {\left(y_{1}\left(t\right) - y_{2}\left(t\right)\right)}^{2} + {\left(z_{1}\left(t\right) - z_{2}\left(t\right)\right)}^{2}}}$

# %%
# Ищем выражение для v через обобщенные импульсы, решая вышесозданную систему уравнений

sol_v_p = []
for i in range(len(V)):
    sol_v_p += solve(eq_p_v[i], V[i])
    disp(sol_v_p[i])
# Out:
# $\displaystyle v_{x_{1}} = -\frac{C v_{x_{2}} - \sqrt{{\left(x_{1}\left(t\right) - x_{2}\left(t\right)\right)}^{2} + {\left(y_{1}\left(t\right) - y_{2}\left(t\right)\right)}^{2} + {\left(z_{1}\left(t\right) - z_{2}\left(t\right)\right)}^{2}} p_{x_{1}}}{\sqrt{{\left(x_{1}\left(t\right) - x_{2}\left(t\right)\right)}^{2} + {\left(y_{1}\left(t\right) - y_{2}\left(t\right)\right)}^{2} + {\left(z_{1}\left(t\right) - z_{2}\left(t\right)\right)}^{2}} m_{1}}$
# $\displaystyle v_{x_{2}} = -\frac{C v_{x_{1}} - \sqrt{{\left(x_{1}\left(t\right) - x_{2}\left(t\right)\right)}^{2} + {\left(y_{1}\left(t\right) - y_{2}\left(t\right)\right)}^{2} + {\left(z_{1}\left(t\right) - z_{2}\left(t\right)\right)}^{2}} p_{x_{2}}}{\sqrt{{\left(x_{1}\left(t\right) - x_{2}\left(t\right)\right)}^{2} + {\left(y_{1}\left(t\right) - y_{2}\left(t\right)\right)}^{2} + {\left(z_{1}\left(t\right) - z_{2}\left(t\right)\right)}^{2}} m_{2}}$
# $\displaystyle v_{y_{1}} = -\frac{C v_{y_{2}} - \sqrt{{\left(x_{1}\left(t\right) - x_{2}\left(t\right)\right)}^{2} + {\left(y_{1}\left(t\right) - y_{2}\left(t\right)\right)}^{2} + {\left(z_{1}\left(t\right) - z_{2}\left(t\right)\right)}^{2}} p_{y_{1}}}{\sqrt{{\left(x_{1}\left(t\right) - x_{2}\left(t\right)\right)}^{2} + {\left(y_{1}\left(t\right) - y_{2}\left(t\right)\right)}^{2} + {\left(z_{1}\left(t\right) - z_{2}\left(t\right)\right)}^{2}} m_{1}}$
# $\displaystyle v_{y_{2}} = -\frac{C v_{y_{1}} - \sqrt{{\left(x_{1}\left(t\right) - x_{2}\left(t\right)\right)}^{2} + {\left(y_{1}\left(t\right) - y_{2}\left(t\right)\right)}^{2} + {\left(z_{1}\left(t\right) - z_{2}\left(t\right)\right)}^{2}} p_{y_{2}}}{\sqrt{{\left(x_{1}\left(t\right) - x_{2}\left(t\right)\right)}^{2} + {\left(y_{1}\left(t\right) - y_{2}\left(t\right)\right)}^{2} + {\left(z_{1}\left(t\right) - z_{2}\left(t\right)\right)}^{2}} m_{2}}$
# $\displaystyle v_{z_{1}} = -\frac{C v_{z_{2}} - \sqrt{{\left(x_{1}\left(t\right) - x_{2}\left(t\right)\right)}^{2} + {\left(y_{1}\left(t\right) - y_{2}\left(t\right)\right)}^{2} + {\left(z_{1}\left(t\right) - z_{2}\left(t\right)\right)}^{2}} p_{z_{1}}}{\sqrt{{\left(x_{1}\left(t\right) - x_{2}\left(t\right)\right)}^{2} + {\left(y_{1}\left(t\right) - y_{2}\left(t\right)\right)}^{2} + {\left(z_{1}\left(t\right) - z_{2}\left(t\right)\right)}^{2}} m_{1}}$
# $\displaystyle v_{z_{2}} = -\frac{C v_{z_{1}} - \sqrt{{\left(x_{1}\left(t\right) - x_{2}\left(t\right)\right)}^{2} + {\left(y_{1}\left(t\right) - y_{2}\left(t\right)\right)}^{2} + {\left(z_{1}\left(t\right) - z_{2}\left(t\right)\right)}^{2}} p_{z_{2}}}{\sqrt{{\left(x_{1}\left(t\right) - x_{2}\left(t\right)\right)}^{2} + {\left(y_{1}\left(t\right) - y_{2}\left(t\right)\right)}^{2} + {\left(z_{1}\left(t\right) - z_{2}\left(t\right)\right)}^{2}} m_{2}}$

# %%
sol_vp = []
for i in range(len(V)):
    vp = sol_v_p[i].lhs() == sol_v_p[i].rhs().subs(sol_v_p)
    #disp(vp)
    v_p = vp.solve(V[i])[0].full_simplify()
    #disp(v_p)
    sol_vp += [v_p]

# %%
# Находим выражение для Гамильтониана исходя из
# выражения энергии через Лагранжиан
# используя вышенайденную подстановку,
# выражающую v через обобщенные импульсы и координаты

H = (Ev).subs(sol_vp).subs(x_to_X)
#disp(H)

# %%
H.variables()
# Out:
# (C,
#  m_1,
#  m_2,
#  p_x_1,
#  p_x_2,
#  p_y_1,
#  p_y_2,
#  p_z_1,
#  p_z_2,
#  x_1,
#  x_2,
#  y_1,
#  y_2,
#  z_1,
#  z_2)

# %%
H
# Out:
# 1/2*(m_2*p_x_1*x_1^2 - 2*m_2*p_x_1*x_1*x_2 + m_2*p_x_1*x_2^2 + m_2*p_x_1*y_1^2 - 2*m_2*p_x_1*y_1*y_2 + m_2*p_x_1*y_2^2 + m_2*p_x_1*z_1^2 - 2*m_2*p_x_1*z_1*z_2 + m_2*p_x_1*z_2^2 - sqrt(x_1^2 - 2*x_1*x_2 + x_2^2 + y_1^2 - 2*y_1*y_2 + y_2^2 + z_1^2 - 2*z_1*z_2 + z_2^2)*C*p_x_2)^2*m_1/(m_1*m_2*x_1^2 - 2*m_1*m_2*x_1*x_2 + m_1*m_2*x_2^2 + m_1*m_2*y_1^2 - 2*m_1*m_2*y_1*y_2 + m_1*m_2*y_2^2 + m_1*m_2*z_1^2 - 2*m_1*m_2*z_1*z_2 + m_1*m_2*z_2^2 - C^2)^2 + 1/2*(m_2*p_y_1*x_1^2 - 2*m_2*p_y_1*x_1*x_2 + m_2*p_y_1*x_2^2 + m_2*p_y_1*y_1^2 - 2*m_2*p_y_1*y_1*y_2 + m_2*p_y_1*y_2^2 + m_2*p_y_1*z_1^2 - 2*m_2*p_y_1*z_1*z_2 + m_2*p_y_1*z_2^2 - sqrt(x_1^2 - 2*x_1*x_2 + x_2^2 + y_1^2 - 2*y_1*y_2 + y_2^2 + z_1^2 - 2*z_1*z_2 + z_2^2)*C*p_y_2)^2*m_1/(m_1*m_2*x_1^2 - 2*m_1*m_2*x_1*x_2 + m_1*m_2*x_2^2 + m_1*m_2*y_1^2 - 2*m_1*m_2*y_1*y_2 + m_1*m_2*y_2^2 + m_1*m_2*z_1^2 - 2*m_1*m_2*z_1*z_2 + m_1*m_2*z_2^2 - C^2)^2 + 1/2*(m_2*p_z_1*x_1^2 - 2*m_2*p_z_1*x_1*x_2 + m_2*p_z_1*x_2^2 + m_2*p_z_1*y_1^2 - 2*m_2*p_z_1*y_1*y_2 + m_2*p_z_1*y_2^2 + m_2*p_z_1*z_1^2 - 2*m_2*p_z_1*z_1*z_2 + m_2*p_z_1*z_2^2 - sqrt(x_1^2 - 2*x_1*x_2 + x_2^2 + y_1^2 - 2*y_1*y_2 + y_2^2 + z_1^2 - 2*z_1*z_2 + z_2^2)*C*p_z_2)^2*m_1/(m_1*m_2*x_1^2 - 2*m_1*m_2*x_1*x_2 + m_1*m_2*x_2^2 + m_1*m_2*y_1^2 - 2*m_1*m_2*y_1*y_2 + m_1*m_2*y_2^2 + m_1*m_2*z_1^2 - 2*m_1*m_2*z_1*z_2 + m_1*m_2*z_2^2 - C^2)^2 + 1/2*(m_1*p_x_2*x_1^2 - 2*m_1*p_x_2*x_1*x_2 + m_1*p_x_2*x_2^2 + m_1*p_x_2*y_1^2 - 2*m_1*p_x_2*y_1*y_2 + m_1*p_x_2*y_2^2 + m_1*p_x_2*z_1^2 - 2*m_1*p_x_2*z_1*z_2 + m_1*p_x_2*z_2^2 - sqrt(x_1^2 - 2*x_1*x_2 + x_2^2 + y_1^2 - 2*y_1*y_2 + y_2^2 + z_1^2 - 2*z_1*z_2 + z_2^2)*C*p_x_1)^2*m_2/(m_1*m_2*x_1^2 - 2*m_1*m_2*x_1*x_2 + m_1*m_2*x_2^2 + m_1*m_2*y_1^2 - 2*m_1*m_2*y_1*y_2 + m_1*m_2*y_2^2 + m_1*m_2*z_1^2 - 2*m_1*m_2*z_1*z_2 + m_1*m_2*z_2^2 - C^2)^2 + 1/2*(m_1*p_y_2*x_1^2 - 2*m_1*p_y_2*x_1*x_2 + m_1*p_y_2*x_2^2 + m_1*p_y_2*y_1^2 - 2*m_1*p_y_2*y_1*y_2 + m_1*p_y_2*y_2^2 + m_1*p_y_2*z_1^2 - 2*m_1*p_y_2*z_1*z_2 + m_1*p_y_2*z_2^2 - sqrt(x_1^2 - 2*x_1*x_2 + x_2^2 + y_1^2 - 2*y_1*y_2 + y_2^2 + z_1^2 - 2*z_1*z_2 + z_2^2)*C*p_y_1)^2*m_2/(m_1*m_2*x_1^2 - 2*m_1*m_2*x_1*x_2 + m_1*m_2*x_2^2 + m_1*m_2*y_1^2 - 2*m_1*m_2*y_1*y_2 + m_1*m_2*y_2^2 + m_1*m_2*z_1^2 - 2*m_1*m_2*z_1*z_2 + m_1*m_2*z_2^2 - C^2)^2 + 1/2*(m_1*p_z_2*x_1^2 - 2*m_1*p_z_2*x_1*x_2 + m_1*p_z_2*x_2^2 + m_1*p_z_2*y_1^2 - 2*m_1*p_z_2*y_1*y_2 + m_1*p_z_2*y_2^2 + m_1*p_z_2*z_1^2 - 2*m_1*p_z_2*z_1*z_2 + m_1*p_z_2*z_2^2 - sqrt(x_1^2 - 2*x_1*x_2 + x_2^2 + y_1^2 - 2*y_1*y_2 + y_2^2 + z_1^2 - 2*z_1*z_2 + z_2^2)*C*p_z_1)^2*m_2/(m_1*m_2*x_1^2 - 2*m_1*m_2*x_1*x_2 + m_1*m_2*x_2^2 + m_1*m_2*y_1^2 - 2*m_1*m_2*y_1*y_2 + m_1*m_2*y_2^2 + m_1*m_2*z_1^2 - 2*m_1*m_2*z_1*z_2 + m_1*m_2*z_2^2 - C^2)^2 + (m_2*p_x_1*x_1^2 - 2*m_2*p_x_1*x_1*x_2 + m_2*p_x_1*x_2^2 + m_2*p_x_1*y_1^2 - 2*m_2*p_x_1*y_1*y_2 + m_2*p_x_1*y_2^2 + m_2*p_x_1*z_1^2 - 2*m_2*p_x_1*z_1*z_2 + m_2*p_x_1*z_2^2 - sqrt(x_1^2 - 2*x_1*x_2 + x_2^2 + y_1^2 - 2*y_1*y_2 + y_2^2 + z_1^2 - 2*z_1*z_2 + z_2^2)*C*p_x_2)*(m_1*p_x_2*x_1^2 - 2*m_1*p_x_2*x_1*x_2 + m_1*p_x_2*x_2^2 + m_1*p_x_2*y_1^2 - 2*m_1*p_x_2*y_1*y_2 + m_1*p_x_2*y_2^2 + m_1*p_x_2*z_1^2 - 2*m_1*p_x_2*z_1*z_2 + m_1*p_x_2*z_2^2 - sqrt(x_1^2 - 2*x_1*x_2 + x_2^2 + y_1^2 - 2*y_1*y_2 + y_2^2 + z_1^2 - 2*z_1*z_2 + z_2^2)*C*p_x_1)*C/((m_1*m_2*x_1^2 - 2*m_1*m_2*x_1*x_2 + m_1*m_2*x_2^2 + m_1*m_2*y_1^2 - 2*m_1*m_2*y_1*y_2 + m_1*m_2*y_2^2 + m_1*m_2*z_1^2 - 2*m_1*m_2*z_1*z_2 + m_1*m_2*z_2^2 - C^2)^2*sqrt(x_1^2 - 2*x_1*x_2 + x_2^2 + y_1^2 - 2*y_1*y_2 + y_2^2 + z_1^2 - 2*z_1*z_2 + z_2^2)) + (m_2*p_y_1*x_1^2 - 2*m_2*p_y_1*x_1*x_2 + m_2*p_y_1*x_2^2 + m_2*p_y_1*y_1^2 - 2*m_2*p_y_1*y_1*y_2 + m_2*p_y_1*y_2^2 + m_2*p_y_1*z_1^2 - 2*m_2*p_y_1*z_1*z_2 + m_2*p_y_1*z_2^2 - sqrt(x_1^2 - 2*x_1*x_2 + x_2^2 + y_1^2 - 2*y_1*y_2 + y_2^2 + z_1^2 - 2*z_1*z_2 + z_2^2)*C*p_y_2)*(m_1*p_y_2*x_1^2 - 2*m_1*p_y_2*x_1*x_2 + m_1*p_y_2*x_2^2 + m_1*p_y_2*y_1^2 - 2*m_1*p_y_2*y_1*y_2 + m_1*p_y_2*y_2^2 + m_1*p_y_2*z_1^2 - 2*m_1*p_y_2*z_1*z_2 + m_1*p_y_2*z_2^2 - sqrt(x_1^2 - 2*x_1*x_2 + x_2^2 + y_1^2 - 2*y_1*y_2 + y_2^2 + z_ ...

# %% [markdown]
# Записываем уравнения Гамильтона
#
# $\dot{p}_i = - \frac{\partial H}{\partial q_i}$
#
# $\dot{q}_i = \frac{\partial H}{\partial p_i}$

# %%
dvars=P+X
dvars
# Out:
# [p_x_1, p_x_2, p_y_1, p_y_2, p_z_1, p_z_2, x_1, x_2, y_1, y_2, z_1, z_2]

# %%
dot_P = []
dot_X = []
for i in range(len(X)):
    dot_p_i = - H.diff(X[i])
    dot_x_i =   H.diff(P[i])
    dot_P += [dot_p_i]
    dot_X += [dot_x_i]
    #disp(dot_p_i)
    #disp(dot_x_i)

# %%
# полученные уравнения Гамильтона обьединяем в систему из 2 уравнений
des = dot_P + dot_X
#disp(des)

# %%
# индуктивные кросс-массы выключены
values0 = [m_1 == 1, m_2 == 1, C == 0]
values0
# Out:
# [m_1 == 1, m_2 == 1, C == 0]

# %%
# индуктивные кросс-массы включены
values1 = [m_1 == 1, m_2 == 1, C == 1]
values1
# Out:
# [m_1 == 1, m_2 == 1, C == 1]

# %%
# в которой делаем подстановку численных значений масс
f1 = [de_i.subs(values1) for de_i in des]
#disp(f)

# %%
# в которой делаем подстановку численных значений масс
f0 = [de_i.subs(values0) for de_i in des]
#disp(f)

# %%
# Solve numerically a system of first-order ordinary differential equations
# using odeint from scipy.integrate module.

# des – right hand sides of the system
# ics – initial conditions
# times – a sequence of time points in which the solution must be found
# dvars – dependent variables. ATTENTION: the order must be the same as in des, that means: d(dvars[i])/dt=des[i]
# ivar – independent variable, optional.

#times = srange(0, 30, 0.01)
times = srange(0, 200, 0.01)

# начальные значения импульсов и координат

#P = [p_x_1, p_x_2, p_y_1, p_y_2, p_z_1, p_z_2]
#X = [  X_1,   X_2,   Y_1,   Y_2,   Z_1,   Z_2]
p0 = [0, 0, 0, 0, 0, 0]
x0 = [2,-2, 0, 0, 0, 0]

sol0 = desolve_odeint(des=f0, ics=p0+x0, times=times, dvars=P+X, ivar=t)
sol1 = desolve_odeint(des=f1, ics=p0+x0, times=times, dvars=P+X, ivar=t)

# %% [markdown]
# # Построение фазовых диаграмм ($p(x)$)

# %%
plt  = line(zip(sol0[:,6], sol0[:,0]), axes_labels=['$x_1$','$p_1$',], color="green")
plt += line(zip(sol0[:,7], sol0[:,1]), axes_labels=['$x_1$','$p_1$',], color="green")
plt += line(zip(sol1[:,6], sol1[:,0]), axes_labels=['$x_1$','$p_1$',], color="red")
plt += line(zip(sol1[:,7], sol1[:,1]), axes_labels=['$x_1$','$p_1$',], color="red")
plt.show(title="Фазовая диаграмма без кроссмасс (green) с кроссмассой (red)\n\n\n")
# Out:
# Graphics object consisting of 4 graphics primitives

# %% [markdown]
# # Построение зависимости обобщённых координат и импульсов от времени

# %%
plt  = line(zip(times,sol0[:,0]), color="green")
plt += line(zip(times,sol1[:,0]), color="red")
plt.show(title="$p_{x_1}$ green - without crossmasses")

plt  = line(zip(times,sol0[:,1]), color="green")
plt += line(zip(times,sol1[:,1]), color="red")
plt.show(title="$p_{x_2}$ green - without crossmasses")

#plt = line(zip(times,sol[:,2]))
#plt.show(title="$p_{y_1}$")

#plt = line(zip(times,sol[:,3]))
#plt.show(title="$p_{y_2}$")

#plt = line(zip(times,sol[:,4]))
#plt.show(title="$p_{z_1}$")

#plt = line(zip(times,sol[:,5]))
#plt.show(title="$p_{z_2}$")
# Out:
# Graphics object consisting of 2 graphics primitives
# Graphics object consisting of 2 graphics primitives

# %%
plt  = line(zip(times,sol0[:,6]), color="green")
plt += line(zip(times,sol1[:,6]), color="red")
plt.show(title="${x_1}$ green - without crossmasses")

plt  = line(zip(times,sol0[:,7]), color="green")
plt += line(zip(times,sol1[:,7]), color="red")
plt.show(title="${x_2}$ green - without crossmasses")

#plt = line(zip(times,sol[:,8]))
#plt.show(title="${y_1}$")

#plt = line(zip(times,sol[:,9]))
#plt.show(title="${y_2}$")

#plt = line(zip(times,sol[:,10]))
#plt.show(title="${z_1}$")

#plt = line(zip(times,sol[:,11]))
#plt.show(title="${z_2}$")
# Out:
# Graphics object consisting of 2 graphics primitives
# Graphics object consisting of 2 graphics primitives

# %% [markdown]
# Включение индуктивных кросс-мас при неизменных собственных массах увеличило частоту осциллятора состоящего из двух леннард-джонсовских атомов, но не изменило амплитуду колебаний

# %%
plt  = line(zip(times,(sol0[:,0]+sol0[:,1])/2), color="green")
plt += line(zip(times,(sol1[:,0]+sol1[:,1])/2), color="red")
plt.show(title="mean momenta ${p_c}$ ")
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
plt  = line(zip(times,(sol0[:,6]+sol0[:,7])/2),color="green")
plt += line(zip(times,(sol1[:,6]+sol1[:,7])/2),color="red")
plt.show(title="coordinate of mass center ${x_c}$ ")
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
# Solve numerically a system of first-order ordinary differential equations
# using odeint from scipy.integrate module.

# des – right hand sides of the system
# ics – initial conditions
# times – a sequence of time points in which the solution must be found
# dvars – dependent variables. ATTENTION: the order must be the same as in des, that means: d(dvars[i])/dt=des[i]
# ivar – independent variable, optional.

#times = srange(0, 30, 0.01)
times = srange(0, 5000, 0.05)

# начальные значения импульсов и координат

#P = [p_x_1, p_x_2, p_y_1, p_y_2, p_z_1, p_z_2]
#X = [  X_1,   X_2,   Y_1,   Y_2,   Z_1,   Z_2]
p0 = [-0.002, +0.002, 0,  0, 0, 0]
x0 = [     2,     -2, 2, -2, 0, 0]

sol0 = desolve_odeint(des=f0, ics=p0+x0, times=times, dvars=P+X, ivar=t)
sol1 = desolve_odeint(des=f1, ics=p0+x0, times=times, dvars=P+X, ivar=t)

# %%
plt  = line(zip(sol0[:,6], sol0[:,0]), axes_labels=['$x$','$p_x$',], color="green")
plt += line(zip(sol0[:,7], sol0[:,1]), axes_labels=['$x$','$p_x$',], color="green")
plt += line(zip(sol1[:,6], sol1[:,0]), axes_labels=['$x$','$p_x$',], color="red")
plt += line(zip(sol1[:,7], sol1[:,1]), axes_labels=['$x$','$p_x$',], color="red")
plt.show(title="Фазовая диаграмма без кроссмасс (green) с кроссмассой (red)\n\n\n")
# Out:
# Graphics object consisting of 4 graphics primitives

# %%
plt  = line(zip(sol0[:,8], sol0[:,2]), axes_labels=['$y$','$p_y$',], color="green")
plt += line(zip(sol0[:,9], sol0[:,3]), axes_labels=['$y$','$p_y$',], color="green")
plt += line(zip(sol1[:,8], sol1[:,2]), axes_labels=['$y$','$p_y$',], color="red")
plt += line(zip(sol1[:,9], sol1[:,3]), axes_labels=['$y$','$p_y$',], color="red")
plt.show(title="Фазовая диаграмма без кроссмасс (green) с кроссмассой (red)\n\n\n")
# Out:
# Graphics object consisting of 4 graphics primitives

# %%
plt  = line(zip(times,sol0[:,0]), color="green")
plt += line(zip(times,sol1[:,0]), color="red")
plt.show(title="$p_{x_1}$ без кроссмасс (green) с кроссмассой (red)")

plt  = line(zip(times,sol0[:,1]), color="green")
plt += line(zip(times,sol1[:,1]), color="red")
plt.show(title="$p_{x_2}$ без кроссмасс (green) с кроссмассой (red)")

plt  = line(zip(times,sol0[:,2]), color="green")
plt += line(zip(times,sol1[:,2]), color="red")
plt.show(title="$p_{y_1}$")

plt  = line(zip(times,sol0[:,3]), color="green")
plt += line(zip(times,sol1[:,3]), color="red")
plt.show(title="$p_{y_2}$")

#plt = line(zip(times,sol[:,4]))
#plt.show(title="$p_{z_1}$")

#plt = line(zip(times,sol[:,5]))
#plt.show(title="$p_{z_2}$")
# Out:
# Graphics object consisting of 2 graphics primitives
# Graphics object consisting of 2 graphics primitives
# Graphics object consisting of 2 graphics primitives
# Graphics object consisting of 2 graphics primitives

# %%
plt  = line(zip(times,sol0[:,6]), color="green")
plt += line(zip(times,sol1[:,6]), color="red")
plt.show(title="${x_1}$ без кроссмасс (green) с кроссмассой (red)")

plt  = line(zip(times,sol0[:,7]), color="green")
plt += line(zip(times,sol1[:,7]), color="red")
plt.show(title="${x_2}$ без кроссмасс (green) с кроссмассой (red)")

plt  = line(zip(times,sol0[:,8]), color="green")
plt += line(zip(times,sol1[:,8]), color="red")
plt.show(title="${y_1}$ без кроссмасс (green) с кроссмассой (red)")

plt  = line(zip(times,sol0[:,9]), color="green")
plt += line(zip(times,sol1[:,9]), color="red")
plt.show(title="${y_2}$ без кроссмасс (green) с кроссмассой (red)")

#plt = line(zip(times,sol[:,10]))
#plt.show(title="${z_1}$")

#plt = line(zip(times,sol[:,11]))
#plt.show(title="${z_2}$")
# Out:
# Graphics object consisting of 2 graphics primitives
# Graphics object consisting of 2 graphics primitives
# Graphics object consisting of 2 graphics primitives
# Graphics object consisting of 2 graphics primitives

# %%
plt  = line(zip(sol0[:,6],sol0[:,8]), color="green")
plt += line(zip(sol1[:,6],sol1[:,8]), color="red")
plt += line(zip(sol0[:,7],sol0[:,9]), color="green")
plt += line(zip(sol1[:,7],sol1[:,9]), color="red")
plt.show(title="$x y$ trajectory без кроссмасс (green) с кроссмассой (red)")

#plt = line(zip(times,sol[:,10]))
#plt.show(title="${z_1}$")

#plt = line(zip(times,sol[:,11]))
#plt.show(title="${z_2}$")
# Out:
# Graphics object consisting of 4 graphics primitives
