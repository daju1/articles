# %%
m = var("m")

# %%
def m_bessel_J_x_div_x (m, x):
    if 0 == x:
        if 1 == m:
            return 1/2
        return 0
    return m * bessel_J(m, x)/(x)

# %%
m_bessel_J_x_div_x(m,x)
# Out:
# m*bessel_J(m, x)/x

# %%
m_bessel_J_x_div_x(0,0)
# Out:
# 0

# %%
m_bessel_J_x_div_x(2, 0.000000000000000001)
# Out:
# 2.50000000000000e-19

# %%
plot (bessel_J(2, x), (x, 0, 5))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
plot (m_bessel_J_x_div_x(3, x), (x, 0, 0.0001))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
m_bessel_J_x_div_x(m, 0)
# Out:
# 0
