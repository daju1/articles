# %% [markdown]
# Противоречие между теориями электромагнитной массы

# %% [markdown]
# РАЗРЕШЕНИЕ СУЩЕСТВУЮЩЕГО ПРОТИВОРЕЧИЯ
# МЕЖДУ ЭЛЕКТРОДИНАМИЧЕСКОЙ И РЕЛЯТИВИСТСКОЙ ТЕОРИЯМИ
# ЭЛЕКТРОМАГНИТНОЙ МАССЫ*$^1$

# %% [markdown]
# *Correzione di una contraddizione tra la teoria elettrodinamica e quella relativistica delle masse elettromagnetiche. Nuovo Cimento, 1923, 25, 159-170

# %% [markdown]
# $^1$ Относительно этого вопроса см. две работы: E. Fermi. Rend. Lincei (5), 1922, 31, 184, 306. [Статья Б5б].

# %% [markdown]
# § 1. Теория электромагнитной массы впервые была развита М. Абрагамом$^2$ еще до открытия теории относительности. Поэтому Абрагам в своих расчетах, естественно, рассматривал массу системы электрических зарядов, жестко связанных между собой в смысле классической механики.

# %% [markdown]
# $^2$ A b r a g a m. Theorie der Elektricitat; R i c h a r d s o n. Electron Theory of Matter, Chap. XI; L o r e n t z. The Theory of Electrons, p. 37.

# %% [markdown]
# Он нашел, что при сферической симметрии системы ее масса зависит от скорости, причем для нулевых или очень малых скоростей она равна$^3$ $\left(\frac{4}{3}\right) \frac{u}{c^2}$ (где $u$ - электростатическая энергия системы и $c$ - скорость света). Для скоростей же $v$, сравнимых с $c$, появляются довольно сложные поправочные члены порядка $\frac{v^2}{c^2}$. Еще до теории относительности Фицджеральд ввел гипотезу о том, что твердые тела испытывают сокращение в направлении их движения в отношении
#
# $$\sqrt{1-\frac{v^2}{c^2}}:1$$

# %% [markdown]
# и Лоренц переработал теорию электромагнитной массы Абрагама, рассмотрев теперь системы, испытывающие это сокращение, а не системы электрических зарядов, жестко связанных в смысле классической механики.

# %% [markdown]
# $^3$ Обычно говорят, что электромагнитная масса равномерно заряженного сферического слоя с общим зарадом $e$ и радиусом $r$ равна $\frac{2}{3} \frac{e^2}{r c^2}$; если же заметить, что электростатическая энергия $u = \frac{1}{2} \frac{e^2}{r}$, то для массы находим как раз $\left(\frac{4}{3}\right) \frac{u}{c^2}$.

# %% [markdown]
# Лоренц нашел, что масса покоя (т. е. предел массы для нулевых скоростей) по-прежнему равна $\left(\frac{4}{3}\right) \frac{u}{c^2}$, а поправочные члены, зависящие от $\frac{v^2}{c^2}$, изменились.

# %% [markdown]
# орава Кауфмана, Бухтравоти других, и савдоваше х нессу
# частиц с-радиоактивных тел и катодных частиц большой скорости, определенно говорили в пользу так называемой теории «деформируемого» электрона Лоренца и против теории «гвердого» электрона Абрагама. Вначале это антерпретировалось пай долабательство исключительно электромаг-нитной природы массы электрона, так как счигалось, что иначе их масса
#
# должна была бы быть постоянна. Впоследствии появление теории относи-тельности привело к тому взгляду, что все массы как электромагнитной, так и другой природы должны зависеть от скорости, равно как и масса деформируемого электрона Лоренца.
# Таким образом, указанные опыты
# оставляли открытым вопрос о том, полностью ли электромагнитна масса электрона, и представляли собой лишь подтверждение теории относитель-ности. С другой стороны, специальная теория относительности, не говоря уже об общей теории относительности, привела к необходимости приписать системе с энергией и массу и/с?; итак, возникло серьезное разногласие между электродинамической теорией Лоренца, которая приписывает сфе-рическому распределению электрического заряда массу покоя (⅓) и/с?, и теорией относительности, согласно которой соответствующая масса равна и/с?.
# Такое разногласие + представляется особенно серьезным, если учесть большую важность понятия электромагнитной массы как основы электронной теории материи.
# Это разногласие показалось мне особенно острым в двух недавних работах 5, в одной из которых, рассматривая электромагнитные массы систем с произвольной симметрией на основании обычных электромагнит-ных теорий, я нашел, что вообще массы представляются не скалярами, а тензорами, естественно переходящими в (⅓/) и/с? при сферической симмет-рии. Исходя из общей теории относительности, в другой работе я рассмотрел вес тех же самых систем и нашел его во всех случаях равным (и/с?)G (где
#
# G -гравитационное ускорение).
# В настоящей работе мы покажем, что различие значений массы, по-
# лученных двумя способами, обусловлено противоречащим принципу
# относительности понятием жесткости, которое используется в электроди-намической теории (даже в теории деформируемого электрона). Эта кон-цепция приводит к массе (3) и/с?, в то время как более обоснованное, со-гласующееся с теорией относительности понятие абсолютно твердого тела приводит к значению и/с.
# Заметим еще, что релятивистская динамика электрона была развита
# М. Борном 6, который, однако, воспользовавшись точкой зрения, по существу не отличающейся от обычной, естественно, нашел для массы покоя
#
# В наших рассуждениях мы берем за основу принцип Гамильтона как наиболее удобный для решения задачи, в которой связи довольно сложны.
# Действительно, наша система электрических зарядов должна иметь связи совсем иного типа, чем связи, рассматриваемые в обычной механике (вследствие принципа относительности система, в зависимости от своей
#
# скорости, будет испытывать лоренцово сокращение). Однако, во избежание недоразумений, сразу заметим, что хотя сокращение Лоренца имеет порядок ос?, его влияние на электромагнитную массу касается ее основных членов (т. е. массы покоя). Поэтому оно ощутимо даже при очень низких скоростях
#
# § 2. Итак, рассмотрим систему электрических зарядов, находящихся
# в абсолютно твердом диэлектрике.
# Предположим, что под действием
# электромагнитного поля,
#
# Обусловленного частично самой системой. Частично же внешними причинами, система находится в состоянии посту
# тельного движения, описывая в пространстве-времени ? мировую трубку.
# Сформулируем точно, что именно следует понимать под поступательным движением абсолютно твердого тела. Для этого рассмотрим некоторую
#
# систему отсчета Лоренца
#
#
# Эйнштейна и предположим, что в данный мо-
# мент времени для нее одна точка системы зарядов имеет скорость, равную нулю; мы будем называть движение поступательным, если для этого момента времени в той же самой системе отсчета все точки нашей системы за-
#
# рядов имеют скорость, равную нулю. Это равносильно утверждению, что мировые линии точек нашеи системы суть трактории,
# ортогональные
# семейству линейных пространств.
# И действительно, в системе отсчета Лоренца - Эйнштейна, в
# которой пространство является одним из прост-
# ранств семейства и
# Временная ось, естественно, перпендикулярна ему вся система находится в покое в нулевой момент времени, поскольку пространство ортогонально пересекает мировые линии всех точек системы.
# При таком определении поступательного движения, по существу принятом
#
# М. Борном, жесткость системы выражается тем фактом, что ее форма в этих пространствах, перпендикулярных
#
# Трубке остается неизменной т. е. все нормальные сечения трубки равны друг другу.
# Чтобы применить к нашему случаю принцип Гамильтона, необходимо знать вариацию движения нашей системы, удовлетворяющую связям данной задачи, т. е. правильно интерпретируемой жесткости. Далее мы покажем, что для электромагнитной массы получается значение (*/3) и/сг
#
# Или (**)в зависимости от того, какая из двух ниже иллюстрируемых и обозначен-ных буквами А и В) вариаций принимается.
#
# Сразу же будет видно, что вариацию А не следует принимать во внимание, поскольку она противоречит принципу относительности. Пусть Т - мировая трубка, описанная системой.
#
# На рисунке пространство (х, у, 2) представлено только одним и серением — осью х, и вместо времени t используется ict, чтобы иметь определенную метрику
#
# Вариация А.
# рассматривается бесконечно малое смещение, жесткое в обычном кинема
#
# тическом смысле; это смещение каждого сечения трубки, параллельного пространству (х, у, z), является параллельным этому пространству. Такую вариацию получим, смещая параллельно оси х (см. рисунок) каждое сечение t = const трубки на произвольный бесконечно малый отрезок. Если мы ограничимся трансляционными смещениями, то бх, бу, б — произ-вольные функции только времени, а St = 0.
#
# Вариация В. В качестве вариации, удовлегворяющей жесткой связи рассмагривается бесконечно малое и жесткое в обычном кинематическом смысле смещение каждого нормального сечепия трубки, перпендикуляр-ное самой трубке. На рисунке такую вариацию получим, смещая каждое нормальное сечение трубки параллельно самому себе на произвольный отрезок.
# Из этих двух вариаций
#
# А явно противоречит принципу относитель-
# ности; ее можно не принимать во внимание, поскольку она даже
# неинвариантна относительно преобразований Лоренца и на самом деле оп-ределяется самой выбранной системой отсчета (х, у, г); она никак не может быть выражением физических понятий,
# rakhx,
# как понятие абсолютно
# твердого тела. Напротив, вариация В явно удовлетворяет указанному условию инвариантности; кроме того, поскольку она зависит только от элементов трубки Т, полностью независимых от положения осей системы отсчега, только она и будег есгественной. Действительно, она основыва-ется на соотвегствующем понягию абсолютно твердого тела виртуальном смещении в такой системе отсчета, по отношению к которой в рассматри-ваемый моменг времени скорость системы зарядов равна нулю. Поверхно-сгно рассуждая, можно было бы думать, что вариации А и В приводят к существенно различным следствиям только при больших скоростях, т. е. когда трубка Т составляет значительный угол с временной осью. Но рас-четы, которые мы будем развивать, сразу покажут, что разница сущест-
#
# венна уже для нулевых скоростей и что А дает для электромагнитной массы (½) и/с3, в то время как В дает и/с3.
#
# § 3. Обозначим через (t, х, у, z), или (Хо, Х,, Х2, Хз), координаты времени и пространства; при этом выбор обозначений определяется только со-
# ображениями удобства. Пусть Фі
# - четырехмерный потенциал и
#
# - электромагнитное поле, а Е и Н
# - напряженности электрического и
# магнитного полей, соотвествующие ему.
#
# Принцип Гамильтона, суммирующий законы Максвелла - Лоренца и
# законы механики, гласит %, что суммарное действие, т. е. сумма действий электромагнитного поля и «магериальных» и электрических
#
# Масс не меняется в результате произвольной вариации фі и координат точек мировых линий электрических зарядов, когорая соответствует связям и равна нулю на границе области интегрирования. В нашем случае «материальных» масс нет, и единственные величины, которые подвергаются варьированию, суть координаты точек мировых линий зарядов; поэтому досгаточно рассмотреть только действие электрических зарядов, т. е.
#
# Здесь de — элемент электрического заряда, и второй интеграл должен быть взят по такому отрезку описанной de мировой линии, который находится
# внутри четырехмерной области G интегрирования.
# Поэтому для каждой
# системы вариаций бх;, соответствующих связям и обращающихся в нуль
# на границе G, должно быть SW = 0, т. е
#
# Теперь необходимо рассмотреть по отдельности результаты, которые
# получаются при подсгановке значений бхі, следующих из вариаций типа
# А или В.
#
# 4. Следствия вариаций типа А. В этом случае область интегрирование сводится просто к ABCD. И действительно, области BCG, ADH не дают никакого вклада  поскольку поскольку все бх, в них равны нулю; это происходит оттого, что на контуре G, и поэтому на пути BG, АН величины бх; должны быть равны нулю, а для постоянного t, т. е. на линиях, параллель-
#
# ных оси х, они должны иметь постоянное значение.
# Если через 4 и
# обозначить моменты времени, соответствующие А и В, то выражение (1) можно записать следующим образом:
#
# (St = 0, а бх, бу, б — функции только времени).
# Поскольку бхі - произвольные функции і, получим три уравнения
#
# и два аналогичных соотношения.
# Если в рассматриваемый момент времени скорость нашей системы истеме отсчета (t, х, у, г) равна нулю, то три соотношения сводятся к един ственному векторному соотношению
# §Ede = 0.
# (2)
# К этому равенству мы пришли бы и без расчетов, если, как это делается
# а также по существу и в цитированной работе
# М. Бобы, предположит в априори, что пестя сила, действующ й сиботе
# му, равна нулю. Нам же хотелось получить равенство (2) из принципа Га-мильтона, чтобы вскрыть его «врожденный» порок, обусловленный тем,
#
# Что она следует из вариации типа А, которые противоречат принципу относительности. Из соотношения (2) сразу следует величина () для електро магнитной массы. Дейсвительно, предположим, что Е сумма поля Е(), обусловленного самой системой, и однородного поля Е(®), обусловленного внешними причинами. Соотношение (2) дает
# §Ede + Ei»Sde= 0.
# Здесь jde = е - заряд, поэтому E(«) {de = F - внешняя) сила. С другой стороны, в случае сферической симметрии как прямые расчеты, так и хорошо известные рассуждения об электромагнитном импульсе • показыва-ют что
# где Г - ускорение.
#
# Предыдущее уравнение сводится тогда к
# F=г;
# и равнучь это уравнение с основным законом динамики точки в -
# m=중블.
#
# § 5. Следствия вариаций типа В. В этом случае рассуждения пре-дыдущего параграфа показывают, что область интегрирования сводится к АВЕ, т. е. к области, заключенной между двумя нормальными сечениями трубки Т. Разложим эту область на бесконечное число слоев бесконечно малой толщины; чтобы рассчитать вклад одного из этих слоев в интеграл (1), воспользуемся его покоящейся системой отсчета, принимая время как бх, бу, О будут произвольными константами. Кроме того, ае то время как ох, бу, к буду провозовсе то со равна нулю, а де, равное в -
# сете слоя, будет изменяться от точки к точке, так как слой имеет в качестве оснований два нормальных, в общем случае не параллельных, сечения.
# Если О — произвольная, но определенная точка слоя, например начало ксординат,
# где dt
# принимает значение dto,
# a K
# — вектор,
# Hal vabuch-
# ный по главной нормали к мировой линии, проходящей через О, и с моду-лем, равным ее кривизне, то ясно, что
# dt = dto [1 - K. (P - O)],
#
# где dt — толщина слоя в точке Р.
# Поскольку скорость равна нулю, имеем просто
#
# и поэтому
# Подставляя эти значения, находим, что вклад такого слоя в интеграл
# (1) равен
#
# Это выражение должно обращаться в нуль для всех значений бх, бу, б, и поэтому из него получаются три соотношения, которые сводятся к
#
# единственному векторному
# Итак, правильное применение принципа Гамильтона привело нас к соотношению (3) вместо соотношения (2). Теперь очень легко проанализировать следствия. Полагая
# E = Ed) + El®),
# находим
# В случае сферической симметрии по-прежнему имеем
# подставляя это выражение в предыдущее, находим, что Е(е) выражается олько через члены, содержащие Г. Поэтому, если пренебрегать членами 10, содержащими Г3, то последним интегралом также можно пренебречь; так
# что получим
#
# Чтобы вычислить интеграл в соотношении (4), заметим, что Е(й) суть
# сумма силы Кулона
#
# Р' — точка с зарядом de' и г = PP') и члена, содержащего Г, которым можно пренебречь (поскольку он дал бы вклад порядка Г3). Тогда наш интеграл становится:
#
# или, заменив Р на Р' (что ничего не изменяет) и взяв полусумму двух по-лученных таким образом значений,
#
# Заметим, что для всех точек в нашем приближении Г - константа и и тому ее можно вынести из-под знака интеграла. Следовательно, х-комп нента предыдущего интеграла есть
#
# Далее, поскольку система обладает сферической симметрией, каждому отрезку PP' соответствует бесконечное число других отрезков, отличающихся только ориентацией. Тогда в трех интегралах мы можем заменить
#
# их средними значениями для всех возможных ориентаций РР':
#
# При этом х-компонента становится равной
#
# Теперь заметим, что выражение
#
# есть не что иное, как электростатическая энергия и; возвращаясь к век-торным обозначениям, найдем, что интеграл, входящий в соотношение
# (4), равен (и/3 сз) Г. Итак, соотношение (4) принимает вид
#
# Отсюда сразу видно, что электромагнитная масса равна и/с?.
