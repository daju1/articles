# %%
# https://www.youtube.com/watch?v=tbuqX1MQ6mI
# Лекция 7. Числа и многочлены Бернулли

a = var("a")
k = var("k")

assume(a, 'real')
assume(k, 'real')

assume(a, 'integer')
assume(k, 'integer')

assume(a > 0)
assume(k > 0)

n = QQ['n'].0

y = QQ['y'].0
j = QQ['j'].0

# %%
for i in range(2):
    print(i)
# Out:
# 0
# 1

# %%
S(k,n) = sum(a^k,a,0,n-1)

# %%
S(k,n)
# Out:
# sum(a^k, a, 0, n - 1)

# %%
S(2,5)
# Out:
# sum(a^2, a, 0, 4)

# %% [markdown]
# ![Screenshot%20from%202021-05-12%2006-12-24.png](attachment:Screenshot%20from%202021-05-12%2006-12-24.png)

# %%
for K in range(50):
    #print(bernoulli(k))
    #print(bernoulli_polynomial(y, k))
    print(((a+1)^(K+1) - a^(K+1)).expand())
    print(sum([binomial(K+1, j) * a^j for j in range(K+1)]))
    print("")
# Out:
# 1
# 1
#
# 2*a + 1
# 2*a + 1
#
# 3*a^2 + 3*a + 1
# 3*a^2 + 3*a + 1
#
# 4*a^3 + 6*a^2 + 4*a + 1
# 4*a^3 + 6*a^2 + 4*a + 1
#
# 5*a^4 + 10*a^3 + 10*a^2 + 5*a + 1
# 5*a^4 + 10*a^3 + 10*a^2 + 5*a + 1
#
# 6*a^5 + 15*a^4 + 20*a^3 + 15*a^2 + 6*a + 1
# 6*a^5 + 15*a^4 + 20*a^3 + 15*a^2 + 6*a + 1
#
# 7*a^6 + 21*a^5 + 35*a^4 + 35*a^3 + 21*a^2 + 7*a + 1
# 7*a^6 + 21*a^5 + 35*a^4 + 35*a^3 + 21*a^2 + 7*a + 1
#
# 8*a^7 + 28*a^6 + 56*a^5 + 70*a^4 + 56*a^3 + 28*a^2 + 8*a + 1
# 8*a^7 + 28*a^6 + 56*a^5 + 70*a^4 + 56*a^3 + 28*a^2 + 8*a + 1
#
# 9*a^8 + 36*a^7 + 84*a^6 + 126*a^5 + 126*a^4 + 84*a^3 + 36*a^2 + 9*a + 1
# 9*a^8 + 36*a^7 + 84*a^6 + 126*a^5 + 126*a^4 + 84*a^3 + 36*a^2 + 9*a + 1
#
# 10*a^9 + 45*a^8 + 120*a^7 + 210*a^6 + 252*a^5 + 210*a^4 + 120*a^3 + 45*a^2 + 10*a + 1
# 10*a^9 + 45*a^8 + 120*a^7 + 210*a^6 + 252*a^5 + 210*a^4 + 120*a^3 + 45*a^2 + 10*a + 1
#
# 11*a^10 + 55*a^9 + 165*a^8 + 330*a^7 + 462*a^6 + 462*a^5 + 330*a^4 + 165*a^3 + 55*a^2 + 11*a + 1
# ...

# %%
sum((a+1)^(K+1) - a^(K+1), a, 0, n-1)
# Out:
# n^50

# %%
sum(((a+1)^(k+1) - a^(k+1)).expand(), a, 0, n-1)
# Out:
# sum((a + 1)^(k + 1) - a^(k + 1), a, 0, n - 1)

# %%
#sum([sum([binomial(k+1, j) * a^j for j in range(k+1)]) for a in range(n)])

# %%
for K in range(50):
    print(bernoulli(K))
    print(bernoulli_polynomial(y, K))
    print("")
# Out:
# 1
# 1
#
# -1/2
# y - 1/2
#
# 1/6
# y^2 - y + 1/6
#
# 0
# y^3 - 3/2*y^2 + 1/2*y
#
# -1/30
# y^4 - 2*y^3 + y^2 - 1/30
#
# 0
# y^5 - 5/2*y^4 + 5/3*y^3 - 1/6*y
#
# 1/42
# y^6 - 3*y^5 + 5/2*y^4 - 1/2*y^2 + 1/42
#
# 0
# y^7 - 7/2*y^6 + 7/2*y^5 - 7/6*y^3 + 1/6*y
#
# -1/30
# y^8 - 4*y^7 + 14/3*y^6 - 7/3*y^4 + 2/3*y^2 - 1/30
#
# 0
# y^9 - 9/2*y^8 + 6*y^7 - 21/5*y^5 + 2*y^3 - 3/10*y
#
# 5/66
# y^10 - 5*y^9 + 15/2*y^8 - 7*y^6 + 5*y^4 - 3/2*y^2 + 5/66
#
# 0
# y^11 - 11/2*y^10 + 55/6*y^9 - 11*y^7 + 11*y^5 - 11/2*y^3 + 5/6*y
#
# -691/2730
# y^12 - 6*y^11 + 11*y^10 - 33/2*y^8 + 22*y^6 - 33/2*y^4 + 5*y^2 - 691/2730
#
# 0
# y^13 - 13/2*y^12 + 13*y^11 - 143/6*y^9 + 286/7*y^7 - 429/10*y^5 + 65/3*y^3 - 691/210*y
#
# 7/6
# y^14 - 7*y^13 + 91/6*y^12 - 1001/30*y^10 + 143/2*y^8 - 1001/10*y^6 + 455/6*y^4 - 691/30*y^2 + 7/6
#
# 0
# y^15 - 15/2*y^14 + 35/2*y^13 - 91/2*y^11 + 715/6*y^9 - 429/2*y^7 + 455/2*y^5 - 691/6*y^3 + 35/2*y
#
# -3617/510
# ...
